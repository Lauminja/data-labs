# %%
#we can use tweepy to access the Twitter API
#Replace the credentials below with your actual credentials for this code to function.
import tweepy
import json

# API_KEY = "YourAPIKey"
# API_SECRET = "YourAPISecret"
# ACCESS_TOKEN = "YourAccessToken"
# ACCESS_TOKEN_SECRET = "YourAccessTokenSecret"

# %%
# #Create a dictionary to store twitter credentials:
# twitter_cred = dict()

# # Enter consumer_key, consumer_secret, access_key and access_secret replacing the '********':
# twitter_cred['API_KEY'] = '0IZz2gkyEzVHFMqacPkvjCgl2'
# twitter_cred['API_SECRET'] = 'DcJgKXSfGaXglhvPxyFHxJnBBQjslT0wzohhcNrEwGzSzQexqm'
# twitter_cred['ACCESS_TOKEN'] = '70675169-HgB14g8mi8KJcD1fHsPWROggWlxJGxm1S1JjX3W8K'
# twitter_cred['ACCESS_TOKEN_SECRET'] = '3FWIEQ7pVYbbHsco2kxJEcuzEB1yTyeUKpk9iNhoCyb4t'

# #Save the information to a json so that it can be reused in code without exposing the secret info to public:

# with open('/Users/laumaustupa/Desktop/Ironhack/Paroles/twitter2.json', 'w') as secret_info:
#     json.dump(twitter_cred, secret_info, indent=4, sort_keys=True)

# # Commented all out not to overwrite the json file with the '*********' instead of keys

# %%
with open('/Users/laumaustupa/Desktop/Ironhack/Paroles/twitter2.json') as cred_data:
    info = json.load(cred_data)
    
API_KEY = info['API_KEY']
API_SECRET = info['API_SECRET']
ACCESS_TOKEN = info['ACCESS_TOKEN']
ACCESS_TOKEN_SECRET = info['ACCESS_TOKEN_SECRET']

auth = tweepy.OAuthHandler(API_KEY, API_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
#Create a function that will send a request to the Twitter API
#If we want to create a data frame that contained 100 users that follow Ironhack on Twitter. 
#We would construct a get_followers function that leverages tweepy's followers method, 
#create a list comprehension of the results, and then turn that into a data frame.

import requests
import pandas as pd
from pandas.io.json import json_normalize

def get_followers(user, count=100):
    followers = api.followers(user, count=count)
    followers = [pd.Series(follower._json) for follower in followers]
    df = pd.DataFrame(followers)
    return df

ironhack = get_followers('ironhack')
ironhack.head(10)
# Out:
#                     id               id_str                  name  \
# 0            176758828            176758828           Maria Macià
# 1  1145861655860957185  1145861655860957185        Founder Wisdom
# 2  1101091177779089409  1101091177779089409         The_real_regy
# 3   940173917494349825   940173917494349825          John Manning
# 4            458763803            458763803             Bob Prado
# 5  1090694961937502208  1090694961937502208    Esther Ruiz Design
# 6            475600344            475600344  David Adrián Cañones
# 7             55057927             55057927         José Carneiro
# 8            434382166            434382166               VICK !!
# 9            502227011            502227011     Fernando Acerenza
#
#        screen_name            location  \
# 0       MariaMacia           Barcelona
# 1    founderwisdom    Perth, Australia
# 2      TheRealRegy
# 3  authoritygrowth        Temecula, CA
# 4        Bob_Prado  São Paulo - Brazil
# ...
