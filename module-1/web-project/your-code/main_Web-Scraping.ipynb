# %% [markdown]
# # Web Scraping

# %% [markdown]
# **Find a web page to scrape and determine the content you would like to scrape from it -
# blogs and news sites are typically good candidates for scraping text content,
# and https://www.wikipedia.org/ is usually a good source for HTML tables (search for "list of...").
# **Scrape the HTML from your chosen page, parse the HTML to extract the necessary information, and either save
# the results to a text (txt) file if it is text or into a CSV file if it is tabular data.
#
# Break the project down into different steps - note the steps covered in web scraping lesson,
# try to follow them, and make adjustments as you encounter the obstacles.
#
# The results should be a file containing the results of your web page scrape.
# Your results should be saved in a folder named output.
# Use comments to describe the steps taken and thought process for obtaining data from the API and web page.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.espace-1789.com/film/affiche'
html = requests.get(url).content
response = BeautifulSoup(html, "lxml")
response
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="fr"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title> A l'affiche | espace 1789</title>
# <meta content="" name="description"/>
# <meta content="initial-scale=1.0" name="viewport"/>
# <link href="/sites/all/themes/espace1789_responsive/favico.png" rel="icon" type="image/png"/>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/modules/system/system.base.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/system/system.menus.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/system/system.messages.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/system/system.theme.css?pv91yr");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/modules/date/date_api/date.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/date/date_popup/themes/datepicker.1.7.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_allocine_xml_parser/css/epail_1789_allocine_xml_parser.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_archives_annee/css/epail_1789_archives_annee.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_film_massdelete/css/epail_1789_film_massdelete.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_flashback_prevnext_block/css/epail_1789_flashback_prevnext_block.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/field/theme/field.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/node/node.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/search/search.css?pv91yr");
# @import url("http://www.espace-1789.com/modules/user/user.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/modules/views/css/views.css?pv91yr");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/modules/ctools/css/ctools.css?pv91yr");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/reset.css?pv91yr");
# @import url("http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/style.css?pv91yr");
# </style>
# <!--[if lte IE 7]>
# <link type="text/css" rel="stylesheet" href="http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/ie.css?pv91yr" media="all" />
# <![endif]-->
# <!--[if IE 6]>
# <link type="text/css" rel="stylesheet" href="http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/ie6.css?pv91yr" media="all" />
# <![endif]-->
# <!-- Core CSS File. The CSS code needed to make eventCalendar works -->
# <link href="/sites/all/themes/espace1789_responsive/css/eventCalendar.css" rel="stylesheet"/>
# <link href="/sites/all/themes/espace1789_responsive/css/eventCalendar_theme.css?1565036650" rel="stylesheet"/>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery-1.8.3.min.js?v=1.8.3" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/jquery-extend-3.4.0.js?v=1.4.4" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/jquery.once.js?v=1.2" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/drupal.js?pv91yr" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/sites/default/files/languages/fr_kn3eOP09-vK6CUFaCtFKKt6mCOkev54VaD7PPghpshg.js?pv91yr" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"espace1789_responsive","theme_token":"b5nB0qIuQR-EoKN4lTPc5FgZjdzroZpQwyl4OI662vk","js":{"misc\/jquery.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"public:\/\/languages\/fr_kn3eOP09-vK6CUFaCtFKKt6mCOkev54VaD7PPghpshg.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"sites\/all\/modules\/epail_1789_allocine_xml_parser\/css\/epail_1789_allocine_xml_parser.css":1,"sites\/all\/modules\/epail_1789_archives_annee\/css\/epail_1789_archives_annee.css":1,"sites\/all\/modules\/epail_1789_archives_cineclub\/css\/epail_1789_archives_cineclub.css":1,"sites\/all\/modules\/epail_1789_archives_evenements\/css\/epail_1789_archives_evenements.css":1,"sites\/all\/modules\/epail_1789_archives_flashback\/css\/epail_1789_archives_flashback.css":1,"sites\/all\/modules\/epail_1789_archives_rendezvous\/css\/epail_1789_archives_rendezvous.css":1,"sites\/all\/modules\/epail_1789_film_massdelete\/css\/epail_1789_film_massdelete.css":1,"sites\/all\/modules\/epail_1789_flashback_prevnext_block\/css\/epail_1789_flashback_prevnext_block.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/reset.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/style.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/ie.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/ie6.css":1}},"urlIsAjaxTrusted":{"\/film\/affiche":true}});
# //--><!]]>
# </script>
# <script src="/sites/all/libraries/jwplayer/jwplayer.js"></script>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery.eventCalendar.js"></script>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery.slides.min.js"></script>
# </head>
# <body class="html not-front not-logged-in one-sidebar sidebar-first page-film page-film-affiche">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Aller au contenu principal</a>
# </div>
# <div id="page-wrapper"><div id="page">
# <header class="without-secondary-menu">
# <a href="/" id="logo" rel="home" title="Accueil">
# <img alt="Accueil" src="http://www.espace-1789.com/sites/default/files/logo.png"/>
# </a>
# <div id="name-and-slogan">
# <div id="site-name">
# <strong>
# <a href="/" rel="home" title="Accueil"><span>espace 1789</span></a>
# </strong>
# </div>
# </div> <!-- /#name-and-slogan -->
# <div id="header-content">
# <div class="menu-smartphone">
# <a class="show-hide-menu" href="#"></a>
# <a class="affiche-direct-link" href=" http://www.espace-1789.com/film/affiche">cinéma cette semaine</a>
# <a class="saison-direct-link" href=" http://www.espace-1789.com/spectacle/saison">spectacles cette semaine</a>
# </div>
# <div class="region region-header">
# <div class="block block-search" id="block-search-form">
# <div class="content">
# <form accept-charset="UTF-8" action="/film/affiche" id="search-block-form" method="post"><div><div class="container-inline">
# <h2 class="element-invisible">Formulaire de recherche</h2>
# <div class="form-item form-type-textfield form-item-search-block-form">
# <label class="element-invisible" for="edit-search-block-form--2">Rechercher </label>
# <input class="form-text" id="edit-search-block-form--2" maxlength="128" name="search_block_form" onblur="if (this.value == '') {this.value = 'Rechercher';}" onfocus="if (this.value == 'Rechercher') {this.value = '';}" placeholder="Rechercher" size="14" title="Indiquer les termes à rechercher" type="text" value="Rechercher"/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="OK"/></div><input name="form_build_id" type="hidden" value="form-dqaxzruwbODPxq0NZ2jB_JWKieIKM5ktfJhyrbFkTuo"/>
# <input name="form_id" type="hidden" value="search_block_form"/>
# </div>
# </div></form> </div>
# </div>
# <div class="block block-epail-1789" id="block-epail-1789-tarifs-cine">
# <div class="content">
# <div class="block block-block contextual-links-region" id="block-block-tarif-cine">
# <a class="tarif-cine-programme" href="http://www.espace-1789.com/sites/default/files/upload/programme/programme.pdf" target="blank" type="application/pdf">téléchargez le programme cinéma</a><a class="tarif-link" href="/tarif-billeterie">les tarifs</a>
# </div> </div>
# </div>
# <div class="block block-block" id="block-block-1">
# <h2 class="element-invisible">ou?</h2>
# <div class="content">
# <p><a href="http://www.espace-1789.com/coordonnées-horaires-accès-bar"><span>ou</span>?</a></p> </div>
# </div>
# </div>
# </div>
# </header>
# <div class="clearfix" id="main-wrapper">
# <div class="share">
# <ul>
# <li><span class="tooltip tooltip-snd">envoyer<br/>  à un ami</span></li>
# <li>
# <script>function fbs_click() {u=location.href;t=document.title;window.open('http://www.facebook.com/sharer.php?u='+encodeURIComponent(u)+'&t='+encodeURIComponent(t),'sharer','toolbar=0,status=0,width=626,height=436');return false;}</script>
# <a class="fb_share_link" href="http://www.facebook.com/share.php?u=&lt;url&gt;" onclick="return fbs_click()" target="_blank"></a>
# <span class="tooltip tooltip-fb">partager<br/>  sur facebook</span></li>
# <li>
# <a class="twitter-share-button" href="javascript:(function(){window.twttr=window.twttr||{};var D=550,A=450,C=screen.height,B=screen.width,H=Math.round((B/2)-(D/2)),G=0,F=document,E;if(C&gt;A){G=Math.round((C/2)-(A/2))}window.twttr.shareWin=window.open('http://twitter.com/share','','left='+H+',top='+G+',width='+D+',height='+A+',personalbar=0,toolbar=0,scrollbars=1,resizable=1');E=F.createElement('script');E.src='http://platform.twitter.com/bookmarklets/share.js?v=1';F.getElementsByTagName('head')[0].appendChild(E)}());"></a>
# <span class="tooltip tooltip-twt">partager<br/> sur tweeter</span> </li>
# </ul>
# </div>
# <div id="sidebar-first">
# <div class="region region-sidebar-first">
# <div class="block block-system block-menu" id="block-system-main-menu">
# <h2>Menu principal</h2>
# <div class="content">
# <ul class="menu clearfix"><li class="first expanded active-trail menu-depth-1 menu-item-408"><a class="active-trail active" href="/film/affiche"><span>Cinéma</span></a><ul class="menu clearfix"><li class="first expanded active-trail menu-depth-2 menu-item-414"><a class="active-trail active" href="/film/affiche"><span>à l'affiche</span></a><ul class="menu clearfix"><li class="first leaf menu-depth-3 menu-item-17372"><a href="/film/pupille"><span>  Pupille</span></a></li><li class="leaf menu-depth-3 menu-item-17864"><a href="/film/female-pleasure"><span>#FEMALE PLEASURE</span></a></li><li class="leaf menu-depth-3 menu-item-17608"><a href="/film/16-levers-de-soleil"><span>16 LEVERS DE SOLEIL</span></a></li><li class="leaf menu-depth-3 menu-item-17202"><a href="/film/3-courts-m%C3%A9trages-en-3d"><span>3 courts métrages en 3D </span></a></li><li class="leaf menu-depth-3 menu-item-17778"><a href="/film/90%E2%80%99s"><span>90’S</span></a></li><li class="leaf menu-depth-3 menu-item-17859"><a href="/film/aladdin"><span>ALADDIN</span></a></li><li class="leaf menu-depth-3 menu-item-17789"><a href="/film/amir-et-mina-les-aventures-du-tapis-volant"><span>AMIR ET MINA : LES AVENTURES DU TAPIS VOLANT</span></a></li><li class="leaf menu-depth-3 menu-item-16836"><a href="/film/apres-demain"><span>APRES DEMAIN</span></a></li><li class="leaf menu-depth-3 menu-item-17692"><a href="/film/ariol-prend-l%E2%80%99avion"><span>ARIOL PREND L’AVION </span></a></li><li class="leaf menu-depth-3 menu-item-17337"><a href="/node/13786"><span>ASAKO I&amp;II </span></a></li><li class="leaf menu-depth-3 menu-item-16239"><a href="/film/assurance-sur-la-mort"><span>ASSURANCE SUR LA MORT</span></a></li><li class="leaf menu-depth-3 menu-item-17116"><a href="/film/amanda"><span>Amanda</span></a></li><li class="leaf menu-depth-3 menu-item-16833"><a href="/film/amin"><span>Amin</span></a></li><li class="leaf menu-depth-3 menu-item-18297"><a href="/film/anna"><span>Anna</span></a></li><li class="leaf menu-depth-3 menu-item-17644"><a href="/film/annulation-projection-je-nous-promets"><span>Annulation projection Je nous promets</span></a></li><li class="leaf menu-depth-3 menu-item-17380"><a href="/node/13792"><span>Another Day Of Life</span></a></li><li class="leaf menu-depth-3 menu-item-17256"><a href="/film/ast%C3%A9rix-le-secret-de-la-potion-magique"><span>Astérix - Le Secret de la Potion Magique</span></a></li><li class="leaf menu-depth-3 menu-item-17335"><a href="/node/13784"><span>Ayka</span></a></li><li class="leaf menu-depth-3 menu-item-17628"><a href="/film/a%C3%AFlo-une-odyss%C3%A9e-en-laponie"><span>Aïlo : une odyssée en Laponie</span></a></li><li class="leaf menu-depth-3 menu-item-17050"><a href="/film/balto-chien-loup-h%C3%A9ros-des-neiges"><span>BALTO CHIEN LOUP, HÉROS DES NEIGES</span></a></li><li class="leaf menu-depth-3 menu-item-16763"><a href="/film/bamse-au-pays-des-voleurs"><span>BAMSE AU PAYS DES VOLEURS</span></a></li><li class="leaf menu-depth-3 menu-item-18092"><a href="/film/bu%C3%B1uel-apr%C3%A8s-l%E2%80%99%C3%A2ge-d%E2%80%99or"><span>BUÑUEL APRÈS L’ÂGE D’OR</span></a></li><li class="leaf menu-depth-3 menu-item-17309"><a href="/node/13781"><span>Border</span></a></li><li class="leaf menu-depth-3 menu-item-17751"><a href="/film/charlie-mon-h%C3%A9ros"><span>CHARLIE MON HÉROS </span></a></li><li class="leaf menu-depth-3 menu-item-18070"><a href="/film/cine-karaoke-bohemian-rhapsody"><span>CIne karaoke : Bohemian Rhapsody</span></a></li><li class="leaf menu-depth-3 menu-item-17020"><a href="/film/cold-war"><span>COLD WAR</span></a></li><li class="leaf menu-depth-3 menu-item-17785"><a href="/film/coming-out"><span>COMING OUT</span></a></li><li class="leaf menu-depth-3 menu-item-18295"><a href="/film/comme-des-b%C3%AAtes-2"><span>COMME DES BÊTES 2</span></a></li><li class="leaf menu-depth-3 menu-item-17697"><a href="/film/comme-si-de-rien-n%E2%80%99%C3%A9tait"><span>COMME SI DE RIEN N’ÉTAIT</span></a></li><li class="leaf menu-depth-3 menu-item-17650 ...
# </div>
# <div class="block block-block" id="block-block-2">
# <div class="content">
# <div id="eventCalendarInline"></div> </div>
# </div>
# </div>
# </div> <!--  /#sidebar-first -->
# <div id="content">
# <!-- 	      <div id="breadcrumb"><h2 class="element-invisible">Vous êtes ici</h2><div class="breadcrumb"><a href="/">Accueil</a></div></div>
#      -->
# <!-- tabs edit delet -->
# <div class="region region-content">
# <div class="block block-epail-1789" id="block-epail-1789-film-semaine-list">
# <div class="content">
# <div id="films-semaine">
# <h3>Films de la semaine</h3>
# </div> </div>
# </div>
# <div class="block block-system" id="block-system-main">
# <div class="content">
# <section id="films-coupdecoeur">
# <div id="blogvision"> <iframe src="http://player.allocine.fr/19584693.html" style="width:480px; height:270px"> </iframe> <br/> <a href="http://www.allocine.fr/film/fichefilm_gen_cfilm=273665.html" rel="noopener noreferrer" target="_blank">Rêves de Jeunesse</a> <br/> <a href="http://www.allocine.fr/video/player_gen_cmedia=19584693&amp;cfilm=273665.html"><strong>Rêves de Jeunesse</strong> Bande-annonce VF</a> </div><div class="description">
# <a href="../film/rêves-de-jeunesse">
# <div class="field-titre">
#     Rêves de jeunesse    </div>
# <div class="field-realisateur">
#             Alain Raoust         </div>
# <div class="short-line"></div>
# <div class="field-legende">
# </div>
# <div class="field-texte">
# </div>
# <!--
#     <div class="field-image">
#         </div> -->
# </a>
# </div>
# <div class="clear"></div>
# </section> <section id="films-affiche">
# <div class="week week-3">
# <h3>Du <em class="placeholder">21</em> au <em class="placeholder">27 Août</em></h3>
# <div class="content-week">
# <ul><li class="affiche-film-item"><a href="../film/yesterday?semaine=4"><img alt="YESTERDAY" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/affiche_3.jpg?itok=XK8zHP1X" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/yesterday?semaine=4"><h4 class="film-spec"><span class="title">YESTERDAY</span></h4></a><h5>Danny Boyle </h5><ul class="seance-film"><li><em>jeu. 22 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:00</span>18:00</span></div><div class="clear"></div></li><li><em>ven. 23 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:10</span>16:10</span></div><div class="clear"></div></li><li><em>sam. 24 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">14:50</span>14:50</span></div><div class="clear"></div></li><li><em>lun. 26 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">20:30</span>20:30</span></div><div class="clear"></div></li></ul></div></li><li class="affiche-film-item"><a href="../film/je-promets-dêtre-sage?semaine=4"><img alt="JE PROMETS D'ÊTRE SAGE" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/4299630.jpg-r_1920_1080-f_jpg-q_x-xxyxx.jpg?itok=AuzbySSP" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/je-promets-dêtre-sage?semaine=4"><h4 class="film-spec"><span class="title">JE PROMETS D'ÊTRE SAGE</span></h4></a><h5> Ronan Le Page </h5><ul class="seance-film"><li><em>mer. 21 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">14:40</span>14:40</span><span class="hour"><span class="tri">18:10</span>18:10</span><span class="hour"><span class="tri">20:40</span>20:40</span></div><div class="clear"></div></li><li><em>jeu. 22 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:30</span>18:30</span><span class="hour"><span class="tri">20:30</span>20:30</span></div><div class="clear"></div></li><li><em>ven. 23 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">14:10</span>14:10</span><span class="hour"><span class="tri">18:30</span>18:30</span></div><div class="clear"></div></li><li><em>sam. 24 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">17:00</span>17:00</span><span class="hour"><span class="tri">21:00</span>21:00</span></div><div class="clear"></div></li><li><em>dim. 25 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:50</span>18:50</span><span class="hour"><span class="tri">20:50</span>20:50</span></div><div class="clear"></div></li><li><em>lun. 26 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">14:10</span>14:10</span><span class="hour"><span class="tri">18:30</span>18:30</span></div><div class="clear"></div></li><li><em>mar. 27 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">13:50</span>13:50</span><span class="hour"><span class="tri">20:50</span>20:50</span></div><div class="clear"></div></li></ul></div></li><li class="affiche-film-item"><a href="../film/rêves-de-jeunesse?semaine=4"><img alt="Rêves de jeunesse" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/affiche_4.jpg?itok=szqC4OZ7" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/rêves-de-jeunesse?semaine=4"><h4 class="film-spec"><span class="title">Rêves de jeunesse</span></h4></a><h5>Alain Raoust </h5><ul class="seance-film"><li><em>mer. 21 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:40</span>18:40</span></div><div class="clear"></div></li><li><em>jeu. 22 aoû</em><div class="heures-seance-film"><span class="hour"><span class="tri">20:10</span>20:10</span></div><div class="clear"></div></li><li><em>ven. 23 aoû</em><div class="heures-seance-film"><spa ...
# <div class="clear"></div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div> <!-- /#content -->
# </div> <!-- /#main-wrapper -->
# </div></div> <!-- /#page, /#page-wrapper -->
# <script src="/sites/all/themes/espace1789_responsive/js/script.js?1565036650"></script>
# <!-- <link rel="stylesheet" href="/sites/all/themes/espace1789_responsive/css/prettyPhoto.css" type="text/css" media="screen" title="prettyPhoto main stylesheet" />
# 		<script src="/sites/all/themes/espace1789_responsive/js/jquery.prettyPhoto.js"></script>-->
# </body>
# </html>

# %%
import re 

string = 'jeu. 22 aoû18:3018:3020:3020:30'
new = re.sub(r'\d\d:\d\d\d\d:\d\d', ' \g<0> ', string)
new
# Out:
# 'jeu. 22 aoû 18:3018:30  20:3020:30 '

# %%
content = response.find_all('li', {'class':'affiche-film-item'})

def get_title(affiche_film):
    titles = affiche_film.find('span', {'class':'title'})
    return(titles.text)

def get_actor(affiche_film):
    actor_main = affiche_film.find('h5') 
    return(actor_main.text)

def get_dates(affiche_film):
    dates = affiche_film.find_all('li')
    dates = [d.text for d in dates]
    new = [re.sub(r'\d\d:\d\d\d\d:\d\d', ' \g<0> ', date) for date in dates]
    new = [re.sub(r'\d\d:\d\d', ' \g<0>', date) for date in dates]
    new_dates = ", ".join(new)
    return(new_dates)

def get_data(content):  
    title = get_title(content)
    actor = get_actor(content)
    dates = get_dates(content)
    return {"title":title, "actor": actor, "dates": dates}

results = []
for c in content:
    results.append(get_data(c))

results
# Out:
# [{'title': 'YESTERDAY',
#   'actor': 'Danny Boyle ',
#   'dates': 'jeu. 22 aoû 18:00 18:00, ven. 23 aoû 16:10 16:10, sam. 24 aoû 14:50 14:50, lun. 26 aoû 20:30 20:30'},
#  {'title': "JE PROMETS D'ÊTRE SAGE",
#   'actor': ' Ronan Le Page ',
#   'dates': 'mer. 21 aoû 14:40 14:40 18:10 18:10 20:40 20:40, jeu. 22 aoû 18:30 18:30 20:30 20:30, ven. 23 aoû 14:10 14:10 18:30 18:30, sam. 24 aoû 17:00 17:00 21:00 21:00, dim. 25 aoû 18:50 18:50 20:50 20:50, lun. 26 aoû 14:10 14:10 18:30 18:30, mar. 27 aoû 13:50 13:50 20:50 20:50'},
#  {'title': 'Rêves de jeunesse',
#   'actor': 'Alain Raoust ',
#   'dates': 'mer. 21 aoû 18:40 18:40, jeu. 22 aoû 20:10 20:10, ven. 23 aoû 18:20 18:20, sam. 24 aoû 19:00 19:00, dim. 25 aoû 14:30 14:30, lun. 26 aoû 16:10 16:10 16:10 16:10 20:50 20:50, mar. 27 aoû 17:10 17:10'},
#  {'title': 'DIEGO MARADONA',
#   'actor': 'Asif Kapadia ',
#   'dates': 'jeu. 22 aoû 14:10 14:10, ven. 23 aoû 20:20 20:20, dim. 25 aoû 17:40 17:40, lun. 26 aoû 18:10 18:10, mar. 27 aoû 20:10 20:10'},
#  {'title': 'Anna',
#   'actor': 'Luc Besson ',
#   'dates': 'mer. 21 aoû 20:10 20:10, ven. 23 aoû 20:30 20:30, sam. 24 aoû 20:50 20:50, dim. 25 aoû 20:15 20:15, mar. 27 aoû 18:30 18:30'},
#  {'title': 'LE ROI LION',
#   'actor': 'Jon Favreau ',
#   'dates': 'mer. 21 aoû 14:30 14:30, jeu. 22 aoû 16:00 16:003D, ven. 23 aoû 14:00 14:00, sam. 24 aoû 18:20 18:20, dim. 25 aoû 14:20 14:203D, lun. 26 aoû 16:00 16:003D, mar. 27 aoû 14:00 14:00'},
#  {'title': 'COMME DES BÊTES 2',
#   'actor': 'Chris Renaud, Jonathan Del Val ',
#   'dates': 'mer. 21 aoû 16:40 16:40, jeu. 22 aoû 14:00 14:00, ven. 23 aoû 16:30 16:30, sam. 24 aoû 15:10 15:10, dim. 25 aoû 16:50 16:50, lun. 26 aoû 14:00 14:00, mar. 27 aoû 16:30 16:30'},
#  {'title': 'LE QUATUOR À CORNES',
#   'actor': 'Programme de courts métrages ',
#   'dates': 'mer. 21 aoû 17:00 17:00, jeu. 22 aoû 16:50 16:50, sam. 24 aoû 17:10 17:10, dim. 25 aoû 16:30 16:30, mar. 27 aoû 16:00 16:00'}]

# %%
import pandas as pd

movies = pd.DataFrame(results, columns=results[0].keys())
movies
# Out:
#                     title                            actor  \
# 0               YESTERDAY                     Danny Boyle
# 1  JE PROMETS D'ÊTRE SAGE                   Ronan Le Page
# 2       Rêves de jeunesse                    Alain Raoust
# 3          DIEGO MARADONA                    Asif Kapadia
# 4                    Anna                      Luc Besson
# 5             LE ROI LION                     Jon Favreau
# 6       COMME DES BÊTES 2  Chris Renaud, Jonathan Del Val
# 7     LE QUATUOR À CORNES    Programme de courts métrages
#
#                                                dates
# 0  jeu. 22 aoû 18:00 18:00, ven. 23 aoû 16:10 16:...
# 1  mer. 21 aoû 14:40 14:40 18:10 18:10 20:40 20:4...
# 2  mer. 21 aoû 18:40 18:40, jeu. 22 aoû 20:10 20:...
# 3  jeu. 22 aoû 14:10 14:10, ven. 23 aoû 20:20 20:...
# 4  mer. 21 aoû 20:10 20:10, ven. 23 aoû 20:30 20:...
# 5  mer. 21 aoû 14:30 14:30, jeu. 22 aoû 16:00 16:...
# 6  mer. 21 aoû 16:40 16:40, jeu. 22 aoû 14:00 14:...
# 7  mer. 21 aoû 17:00 17:00, jeu. 22 aoû 16:50 16:...

# %%
#Export csv:
movies.to_csv('../output/movies.csv', index=False)

# %%
#Other url:

url = 'https://www.vinted.fr/enfants/accessoires'
html = requests.get(url).content
response = BeautifulSoup()
response

# %%
#create a function for each item to find and then call one general function for all:

def get_title(bs4_tag):
    result = bs4_tag.find('img', {'class':'js-item-thumbnail item-thumbnail lazy-thumbnail __act_as_lazy'})
    result = result.get('alt')
    return(result)   
    
def get_brand(bs4_tag):
    result = bs4_tag.find("a", {"class":"item-box__brand"})
    if result == None:
        return "None"
    else:
        return(result.text)

def get_price(bs4_tag):
    result = bs4_tag.find("span")
    return(result.text)

def get_description(bs4_tag):
    result = bs4_tag.find("div", {"class":"media__placeholder"})
    return(result.text.replace('\n', ' '))    

def get_data(content):
    
    title = get_title(content)
    brand = get_brand(content)
    price = get_price(content)
    description = get_description(content)
    
    return {"title":title, "price": price, "brand": brand, "description": description}

# %%
#Add pagination to scrap several pages:

results = []
for i in range(10):
    url = "https://www.vinted.fr/enfants/accessoires?page={i}"
    r = requests.get(url).content
    response = BeautifulSoup(html, "lxml")
    contents = response.find_all('div', {'class':'is-visible item-box__container'})
    for content in contents:
        results.append(get_data(content))
      
results
# Out:
# [{'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '},
#  {'title': "chapeau bébé 18- 23 mois p'tit bisous (taille 3)",
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             très bon état              '},
#  {'title': 'Bonnet petit bateau ',
#   'price': '2,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             Bonnet petit bateau a rayures  43 - 45 Cm               '},
#  {'title': 'Set bonnet écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'ORCHESTRA',
#   'description': '   ORCHESTRA             Orchestra Très bon état Une écharpe Un bonnet doublé Bonnet taille 53 cm Convient à enfant 4/5 ans               '},
#  {'title': 'Set bonnet et écharpe garçon ',
#   'price': '3,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Très bon etat Un bonnet doublé Une écharpe doublée Taille 86/92 noté dans le bonnet  Convient pour enfant de 2/3 ans pas plus              '},
#  {'title': 'Casquette ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Taille 46 6 mois environ               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'Du pareil au même',
#   'description': '   Du pareil au même             Bonnet rigolo pour bébé  tient bien chaud : polaire doublé tissus ,  très bon état               '},
#  {'title': "Bonnet d.aviateur «car's»",
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Doublure chaude   En bon état              '},
#  {'title': 'écharpe et bonnet ',
#   'price': '2,00 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             ensemble chaud 😍              '},
#  {'title': 'Bonnet taille 50 et gants ',
#   'price': '2,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             très bon état               '},
#  {'title': 'Bonnet ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bonnet taille 3mois              '},
#  {'title': 'Chapeau bob',
#   'price': '1,00 €',
#   'brand': 'H&M',
#   'description': "   H&M             Beige 12-18 mois mais plutôt 18 mois 1 tache à l'intérieur du chapeau non visible de l'extérieur N’hésitez à regarder mes autres articles...              "},
#  {'title': 'Bonnet naissance ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': "             bonnet naissance mixte blanc pour la maternité   juste lavé je ne m'en suis pas servi               "},
#  {'title': 'Casquette garçon 57/59 ',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': "             Incontournable de l'été,  la casquette !! Taille 57/59 . Très bon état . Bleu Marine . Deco rivets dorés.  Écusson rouge/Bordeau  #carole...              "},
#  {'title': 'Casquette bébé garçon 50 cm 18 24 mois',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette bébé en très bon état. Tiens bien sans trop serrer la tête de bout de choux              '},
#  {'title': 'Chapeau / bob',
#   'price': '4,00 €',
#   'brand': 'Absorba',
#   'description': '   Absorba             Jamais porté                '},
#  {'title': 'Gants chauds unisexe ',
#   'price': '2,00 €',
#   'brand': 'TISSAIA',
#   'description': '   TISSAIA             Jamais portés, doublés de polaire pour avoir bien chaud.  Avec ficelle qui passe dans le manteau.  Etiquette coupée à l’intérieur du gant...              '},
#  {'title': 'Moufle gant de ski',
#   'price': '1,00 €',
#   'brand': 'GANT',
#   'description': '   GANT             12-36 mois               '},
#  {'title': 'Casquette tape à l’œil 3/4 ans',
#   'price': '3,00 €',
#   'brand': 'Tape à l’œil',
#   'description': '   Tape à l’œil             bon état                '},
#  {'title': 'casquette gavroche',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             violette style gavroche              '},
#  {'title': 'Bob bébé ',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bob 1-3 mois              '},
#  {'title': 'Casquette noire Hugo Boss taille 54',
#   'price': '25,00 €',
#   'brand': 'HUGO BOSS',
#   'description': '   HUGO BOSS             Portée 1 ou 2 fois.               '},
#  {'title': 'Lot de 2 ceintures en toile garçon',
#   'price': '1,50 €',
#   'brand': 'None',
#   'description': '             En parfait état.  #vanes12moisgarçon  #12moisgarçon  #garcon12mois  #ceinturegarcon #lotdeceintures #accessoiresgarcon               '},
#  {'title': 'Bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet 47 cm               '},
#  {'title': 'ensemble bonnet',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             12 mois 1 cagoule et un bonnet              '}]

# %%
#Create a pandas dataframe:

import pandas as pd

df = pd.DataFrame(results, columns=results[0].keys())
df
# Out:
#                                                 title    price  \
# 0    chapeau bébé 18- 23 mois p'tit bisous (taille 3)   1,00 €
# 1                                Bonnet petit bateau    2,00 €
# 2                          Set bonnet écharpe garçon    3,00 €
# 3                       Set bonnet et écharpe garçon    3,00 €
# 4                                          Casquette    1,00 €
# 5                                             Bonnet    2,00 €
# 6                           Bonnet d.aviateur «car's»   2,00 €
# 7                                  écharpe et bonnet    2,00 €
# 8                          Bonnet taille 50 et gants    2,00 €
# 9                                             Bonnet    2,00 €
# 10                                        Chapeau bob   1,00 €
# 11                                  Bonnet naissance    1,00 €
# 12                            Casquette garçon 57/59    2,00 €
# 13             Casquette bébé garçon 50 cm 18 24 mois   1,00 €
# 14                                      Chapeau / bob   4,00 €
# 15                              Gants chauds unisexe    2,00 €
# 16                                 Moufle gant de ski   1,00 €
# 17                     Casquette tape à l’œil 3/4 ans   3,00 €
# 18                                 casquette gavroche   2,00 €
# 19                                          Bob bébé    1,00 €
# 20                Casquette noire Hugo Boss taille 54  25,00 €
# 21                 Lot de 2 ceintures en toile garçon   1,50 €
# 22                                             Bonnet   1,00 €
# 23                                    ensemble bonnet   1,00 €
# 24   chapeau bébé 18- 23 mois p'tit bisous (taille 3)   1,00 €
# 25                               Bonnet petit bateau    2,00 €
# 26                         Set bonnet écharpe garçon    3,00 €
# 27                      Set bonnet et écharpe garçon    3,00 €
# 28                                         Casquette    1,00 €
# 29                                            Bonnet    2,00 €
# ..                                                ...      ...
# 210                                casquette gavroche   2,00 €
# 211                                         Bob bébé    1,00 €
# 212               Casquette noire Hugo Boss taille 54  25,00 €
# 213                Lot de 2 ceintures en toile garçon   1,50 €
# 214                                            Bonnet   1,00 €
# 215                                   ensemble bonnet   1,00 €
# 216  chapeau bébé 18- 23 mois p'tit bisous (taille 3)   1,00 €
# 217                              Bonnet petit bateau    2,00 €
# 218                        Set bonnet écharpe garçon    3,00 €
# 219                     Set bonnet et écharpe garçon    3,00 €
# 220                                        Casquette    1,00 €
# 221                                           Bonnet    2,00 €
# 222                         Bonnet d.aviateur «car's»   2,00 €
# 223                                écharpe et bonnet    2,00 €
# 224                        Bonnet taille 50 et gants    2,00 €
# 225                                           Bonnet    2,00 €
# 226                                       Chapeau bob   1,00 €
# 227                                 Bonnet naissance    1,00 €
# 228                           Casquette garçon 57/59    2,00 €
# 229            Casquette bébé garçon 50 cm 18 24 mois   1,00 €
# 230                                     Chapeau / bob   4,00 €
# 231                             Gants chauds unisexe    2,00 €
# 232                                Moufle gant de ski   1,00 €
# 233                    Casquette tape à l’œil 3/4 ans   3,00 €
# 234                                casquette gavroche   2,00 €
# 235                                         Bob bébé    1,00 €
# 236               Casquette noire Hugo Boss taille 54  25,00 €
# 237                Lot de 2 ceintures en toile garçon   1,50 €
# 238                                            Bonnet   1,00 €
# 239                                   ensemble bonnet   1,00 €
#
#                  brand                                        description
# 0                 None                        très bon état
# 1         Petit Bateau     Petit Bateau             Bonnet petit batea...
# 2            ORCHESTRA     ORCHESTRA             Orchestra Très bon ét...
# 3                 Hema     Hema             Très bon etat Un bonnet do...
# 4                 None               Taille 46 6 mois environ         ...
# 5    Du pareil au même     Du pareil au même             Bonnet rigolo...
# 6                 None               Doublure chaude   En bon état    ...
# 7               okaïdi     okaïdi             ensemble chaud 😍        ...
# 8               Disney     Disney             très bon état           ...
# 9                 None                  Bonnet taille 3mois
# 10                 H&M     H&M             Beige 12-18 mois mais plutô...
# 11                None               bonnet naissance mixte blanc pour...
# 12                None               Incontournable de l'été,  la casq...
# 13                None               Casquette bébé en très bon état. ...
# 14             Absorba     Absorba             Jamais porté           ...
# 15             TISSAIA     TISSAIA             Jamais portés, doublés ...
# 16                GANT         GANT             12-36 mois
# 17        Tape à l’œil     Tape à l’œil             bon état          ...
# 18                None               violette style gavroche          ...
# 19                None                         Bob 1-3 mois
# 20           HUGO BOSS     HUGO BOSS             Portée 1 ou 2 fois.  ...
# 21                None               En parfait état.  #vanes12moisgar...
# 22                None                        Bonnet 47 cm
# 23                None               12 mois 1 cagoule et un bonnet   ...
# 24                None                        très bon état
# 25        Petit Bateau     Petit Bateau             Bonnet petit batea...
# 26           ORCHESTRA     ORCHESTRA             Orchestra Très bon ét...
# 27                Hema     Hema             Très bon etat Un bonnet do...
# 28                None               Taille 46 6 mois environ         ...
# 29   Du pareil au même     Du pareil au même             Bonnet rigolo...
# ..                 ...                                                ...
# 210               None               violette style gavroche          ...
# 211               None                         Bob 1-3 mois
# 212          HUGO BOSS     HUGO BOSS             Portée 1 ou 2 fois.  ...
# 213               None               En parfait état.  #vanes12moisgar...
# 214               None                        Bonnet 47 cm
# 215               None               12 mois 1 cagoule et un bonnet   ...
# 216               None                        très bon état
# 217       Petit Bateau     Petit Bateau             Bonnet petit batea...
# 218          ORCHESTRA     ORCHESTRA             Orchestra Très bon ét...
# 219               Hema     Hema             Très bon etat Un bonnet do...
# 220               None               Taille 46 6 mois environ         ...
# 221  Du pareil au même     Du pareil au même             Bonnet rigolo...
# 222               None               Doublure chaude   En bon état    ...
# 223             okaïdi     okaïdi             ensemble chaud 😍        ...
# 224             Disney     Disney             très bon état           ...
# 225               None                  Bonnet taille 3mois
# 226                H&M     H&M             Beige 12-18 mois mais plutô...
# 227               None               bonnet naissance mixte blanc pour...
# 228               None               Incontournable de l'été,  la casq...
# 229               None               Casquette bébé en très bon état. ...
# 230            Absorba     Absorba             Jamais porté           ...
# 231            TISSAIA     TISSAIA             Jamais portés, doublés ...
# 232               GANT         GANT             12-36 mois
# 233       Tape à l’œil     Tape à l’œil             bon état          ...
# 234               None               violette style gavroche          ...
# 235               None                         Bob 1-3 mois
# 236          HUGO BOSS     HUGO BOSS             Portée 1 ou 2 fois.  ...
# 237               None               En parfait état.  #vanes12moisgar...
# 238               None                        Bonnet 47 cm
# 239               None               12 mois 1 cagoule et un bonnet   ...
#
# [240 rows x 4 columns]

# %%
#Export csv:
df.to_csv('../output/vinted.csv', index=False)
