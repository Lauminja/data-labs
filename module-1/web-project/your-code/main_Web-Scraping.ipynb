# %% [markdown]
# # Web Scraping

# %% [markdown]
# **Find a web page to scrape and determine the content you would like to scrape from it -
# blogs and news sites are typically good candidates for scraping text content,
# and https://www.wikipedia.org/ is usually a good source for HTML tables (search for "list of...").
# **Scrape the HTML from your chosen page, parse the HTML to extract the necessary information, and either save
# the results to a text (txt) file if it is text or into a CSV file if it is tabular data.
#
# Break the project down into different steps - note the steps covered in web scraping lesson,
# try to follow them, and make adjustments as you encounter the obstacles.
#
# The results should be a file containing the results of your web page scrape.
# Your results should be saved in a folder named output.
# Use comments to describe the steps taken and thought process for obtaining data from the API and web page.

# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.espace-1789.com/film/affiche'
html = requests.get(url).content
response = BeautifulSoup(html, "lxml")
response
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="fr"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <title> A l'affiche | espace 1789</title>
# <meta content="" name="description"/>
# <meta content="initial-scale=1.0" name="viewport"/>
# <link href="/sites/all/themes/espace1789_responsive/favico.png" rel="icon" type="image/png"/>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/modules/system/system.base.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/system/system.menus.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/system/system.messages.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/system/system.theme.css?pxpzmv");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/modules/date/date_api/date.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/date/date_popup/themes/datepicker.1.7.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_allocine_xml_parser/css/epail_1789_allocine_xml_parser.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_archives_annee/css/epail_1789_archives_annee.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_film_massdelete/css/epail_1789_film_massdelete.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/epail_1789_flashback_prevnext_block/css/epail_1789_flashback_prevnext_block.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/field/theme/field.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/node/node.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/search/search.css?pxpzmv");
# @import url("http://www.espace-1789.com/modules/user/user.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/modules/views/css/views.css?pxpzmv");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/modules/ctools/css/ctools.css?pxpzmv");
# </style>
# <style media="all" type="text/css">
# @import url("http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/reset.css?pxpzmv");
# @import url("http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/style.css?pxpzmv");
# </style>
# <!--[if lte IE 7]>
# <link type="text/css" rel="stylesheet" href="http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/ie.css?pxpzmv" media="all" />
# <![endif]-->
# <!--[if IE 6]>
# <link type="text/css" rel="stylesheet" href="http://www.espace-1789.com/sites/all/themes/espace1789_responsive/css/ie6.css?pxpzmv" media="all" />
# <![endif]-->
# <!-- Core CSS File. The CSS code needed to make eventCalendar works -->
# <link href="/sites/all/themes/espace1789_responsive/css/eventCalendar.css" rel="stylesheet"/>
# <link href="/sites/all/themes/espace1789_responsive/css/eventCalendar_theme.css?1569059690" rel="stylesheet"/>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery-1.8.3.min.js?v=1.8.3" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/jquery-extend-3.4.0.js?v=1.4.4" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/jquery.once.js?v=1.2" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/misc/drupal.js?pxpzmv" type="text/javascript"></script>
# <script src="http://www.espace-1789.com/sites/default/files/languages/fr_kn3eOP09-vK6CUFaCtFKKt6mCOkev54VaD7PPghpshg.js?pxpzmv" type="text/javascript"></script>
# <script type="text/javascript">
# <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"espace1789_responsive","theme_token":"y7GwrK95CO4heXGVqm5DmNFrod5r_XaGfr2C7wtSkqA","js":{"misc\/jquery.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"public:\/\/languages\/fr_kn3eOP09-vK6CUFaCtFKKt6mCOkev54VaD7PPghpshg.js":1},"css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/modules\/date\/date_api\/date.css":1,"sites\/all\/modules\/date\/date_popup\/themes\/datepicker.1.7.css":1,"sites\/all\/modules\/epail_1789_allocine_xml_parser\/css\/epail_1789_allocine_xml_parser.css":1,"sites\/all\/modules\/epail_1789_archives_annee\/css\/epail_1789_archives_annee.css":1,"sites\/all\/modules\/epail_1789_archives_cineclub\/css\/epail_1789_archives_cineclub.css":1,"sites\/all\/modules\/epail_1789_archives_evenements\/css\/epail_1789_archives_evenements.css":1,"sites\/all\/modules\/epail_1789_archives_flashback\/css\/epail_1789_archives_flashback.css":1,"sites\/all\/modules\/epail_1789_archives_rendezvous\/css\/epail_1789_archives_rendezvous.css":1,"sites\/all\/modules\/epail_1789_film_massdelete\/css\/epail_1789_film_massdelete.css":1,"sites\/all\/modules\/epail_1789_flashback_prevnext_block\/css\/epail_1789_flashback_prevnext_block.css":1,"modules\/field\/theme\/field.css":1,"modules\/node\/node.css":1,"modules\/search\/search.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/views\/css\/views.css":1,"sites\/all\/modules\/ctools\/css\/ctools.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/reset.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/style.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/ie.css":1,"sites\/all\/themes\/espace1789_responsive\/css\/ie6.css":1}},"urlIsAjaxTrusted":{"\/film\/affiche":true}});
# //--><!]]>
# </script>
# <script src="/sites/all/libraries/jwplayer/jwplayer.js"></script>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery.eventCalendar.js"></script>
# <script src="/sites/all/themes/espace1789_responsive/js/jquery.slides.min.js"></script>
# </head>
# <body class="html not-front not-logged-in one-sidebar sidebar-first page-film page-film-affiche">
# <div id="skip-link">
# <a class="element-invisible element-focusable" href="#main-content">Aller au contenu principal</a>
# </div>
# <div id="page-wrapper"><div id="page">
# <header class="without-secondary-menu">
# <a href="/" id="logo" rel="home" title="Accueil">
# <img alt="Accueil" src="http://www.espace-1789.com/sites/default/files/logo.png"/>
# </a>
# <div id="name-and-slogan">
# <div id="site-name">
# <strong>
# <a href="/" rel="home" title="Accueil"><span>espace 1789</span></a>
# </strong>
# </div>
# </div> <!-- /#name-and-slogan -->
# <div id="header-content">
# <div class="menu-smartphone">
# <a class="show-hide-menu" href="#"></a>
# <a class="affiche-direct-link" href=" http://www.espace-1789.com/film/affiche">cinéma cette semaine</a>
# <a class="saison-direct-link" href=" http://www.espace-1789.com/spectacle/saison">spectacles cette semaine</a>
# </div>
# <div class="region region-header">
# <div class="block block-search" id="block-search-form">
# <div class="content">
# <form accept-charset="UTF-8" action="/film/affiche" id="search-block-form" method="post"><div><div class="container-inline">
# <h2 class="element-invisible">Formulaire de recherche</h2>
# <div class="form-item form-type-textfield form-item-search-block-form">
# <label class="element-invisible" for="edit-search-block-form--2">Rechercher </label>
# <input class="form-text" id="edit-search-block-form--2" maxlength="128" name="search_block_form" onblur="if (this.value == '') {this.value = 'Rechercher';}" onfocus="if (this.value == 'Rechercher') {this.value = '';}" placeholder="Rechercher" size="14" title="Indiquer les termes à rechercher" type="text" value="Rechercher"/>
# </div>
# <div class="form-actions form-wrapper" id="edit-actions"><input class="form-submit" id="edit-submit" name="op" type="submit" value="OK"/></div><input name="form_build_id" type="hidden" value="form-olDmNdSr3WXgSwl64FIwSiLwN22Tp3QkIEC4SBjsMM0"/>
# <input name="form_id" type="hidden" value="search_block_form"/>
# </div>
# </div></form> </div>
# </div>
# <div class="block block-epail-1789" id="block-epail-1789-tarifs-cine">
# <div class="content">
# <div class="block block-block contextual-links-region" id="block-block-tarif-cine">
# <a class="tarif-cine-programme" href="http://www.espace-1789.com/sites/default/files/upload/programme/programme.pdf" target="blank" type="application/pdf">téléchargez le programme cinéma</a><a class="tarif-link" href="/tarif-billeterie">les tarifs</a>
# </div> </div>
# </div>
# <div class="block block-block" id="block-block-1">
# <h2 class="element-invisible">ou?</h2>
# <div class="content">
# <p><a href="http://www.espace-1789.com/coordonnées-horaires-accès-bar"><span>ou</span>?</a></p> </div>
# </div>
# </div>
# </div>
# </header>
# <div class="clearfix" id="main-wrapper">
# <div class="share">
# <ul>
# <li><span class="tooltip tooltip-snd">envoyer<br/>  à un ami</span></li>
# <li>
# <script>function fbs_click() {u=location.href;t=document.title;window.open('http://www.facebook.com/sharer.php?u='+encodeURIComponent(u)+'&t='+encodeURIComponent(t),'sharer','toolbar=0,status=0,width=626,height=436');return false;}</script>
# <a class="fb_share_link" href="http://www.facebook.com/share.php?u=&lt;url&gt;" onclick="return fbs_click()" target="_blank"></a>
# <span class="tooltip tooltip-fb">partager<br/>  sur facebook</span></li>
# <li>
# <a class="twitter-share-button" href="javascript:(function(){window.twttr=window.twttr||{};var D=550,A=450,C=screen.height,B=screen.width,H=Math.round((B/2)-(D/2)),G=0,F=document,E;if(C&gt;A){G=Math.round((C/2)-(A/2))}window.twttr.shareWin=window.open('http://twitter.com/share','','left='+H+',top='+G+',width='+D+',height='+A+',personalbar=0,toolbar=0,scrollbars=1,resizable=1');E=F.createElement('script');E.src='http://platform.twitter.com/bookmarklets/share.js?v=1';F.getElementsByTagName('head')[0].appendChild(E)}());"></a>
# <section id="films-coupdecoeur">
# <div id="blogvision"> <iframe src="http://player.allocine.fr/19584093.html" style="width:480px; height:270px"> </iframe> <br/> <a href="http://www.allocine.fr/film/fichefilm_gen_cfilm=265621.html" rel="noopener noreferrer" target="_blank">Portrait de la jeune fille en feu</a> <br/> <a href="http://www.allocine.fr/video/player_gen_cmedia=19584093&amp;cfilm=265621.html"><strong>Portrait de la jeune fille en feu</strong> Bande-annonce VF</a> </div><div class="description">
# <a href="../film/portrait-de-la-jeune-fille-en-feu">
# <div class="field-titre">
#     PORTRAIT DE LA JEUNE FILLE EN FEU     </div>
# <div class="field-realisateur">
#             Céline Sciamma         </div>
# <div class="short-line"></div>
# <div class="field-legende">
# </div>
# <div class="field-texte">
#             Rencontre avec Céline Sciamma - dimanche 22 septembre à 20h
# sur nos écrans du 18 septembre au 1er octobre. .  en sortie nationale        </div>
# <!--
#     <div class="field-image">
#         </div> -->
# </a>
# </div>
# <div class="clear"></div>
# </section> <section id="films-affiche">
# <div class="week week-0">
# <h3>Du <em class="placeholder">18</em> au <em class="placeholder">24 Septembre</em></h3>
# <div class="content-week">
# <ul><li class="affiche-film-item"><a href="../film/le-daim?semaine=1"><img alt="LE DAIM " height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/affichebd_7.jpg?itok=bc_Vgz2B" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/le-daim?semaine=1"><h4 class="film-spec"><span class="title">LE DAIM </span></h4></a><h5>Quentin Dupieux </h5><ul class="seance-film"><li><em>jeu. 19 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">15:50</span>15:50</span></div><div class="clear"></div></li><li><em>ven. 20 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">19:00</span>19:00</span></div><div class="clear"></div></li><li><em>dim. 22 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:10</span>18:10</span></div><div class="clear"></div></li><li><em>lun. 23 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">20:20</span>20:20</span></div><div class="clear"></div></li></ul></div></li><li class="affiche-film-item"><a href="../film/ma-folle-semaine-avec-tess?semaine=1"><img alt="MA FOLLE SEMAINE AVEC TESS" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/5897700.jpg-r_1920_1080-f_jpg-q_x-xxyxx.jpg?itok=l8ztfUWU" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/ma-folle-semaine-avec-tess?semaine=1"><h4 class="film-spec"><span class="title">MA FOLLE SEMAINE AVEC TESS</span><span class="jp-spec">jeune public</span></h4></a><h5>De Steven Wouterlood </h5><ul class="seance-film"><li><em>mer. 18 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">10:00</span>10:00</span><span class="hour"><span class="tri">14:40</span>14:40</span></div><div class="clear"></div></li><li><em>dim. 22 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">14:20</span>14:20</span><span class="hour"><span class="tri">16:20</span>16:20</span></div><div class="clear"></div></li><li><em>lun. 23 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:30</span><span class="special">18:30<span class="vo-spec">vo</span></span></span></div><div class="clear"></div></li><li><em>mar. 24 sep</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:30</span><span class="special">16:30<span class="vo-spec">vo</span></span></span></div><div class="clear"></div></li></ul></div></li><li class="affiche-film-item"><a href="../film/un-petit-air-de-famille?semaine=1"><img alt="UN PETIT AIR DE FAMILLE " height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches
oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">19:00</span>19:00</span></div><div class="clear"></div></li><li><em>dim. 06 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:00</span>16:00</span><span class="hour"><span class="tri">18:10</span>18:10</span></div><div class="clear"></div></li><li><em>lun. 07 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:40</span>18:40</span></div><div class="clear"></div></li><li><em>mar. 08 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:00</span>18:00</span></div><div class="clear"></div></li></ul></div></li><li class="affiche-film-item"><a href="../film/port-authority?semaine=3"><img alt="PORT AUTHORITY" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/0823143.jpg-r_1920_1080-f_jpg-q_x-xxyxx.jpg?itok=RLjHHSxr" typeof="foaf:Ima ...
# <div class="clear"></div>
# </div>
# <div class="week week-3">
# <h3>Du <em class="placeholder">09</em> au <em class="placeholder">15 Octobre</em></h3>
# <div class="content-week">
# <ul><li class="affiche-film-item"><a href="../film/ceux-qui-travaillent?semaine=4"><img alt="CEUX QUI TRAVAILLENT" height="160" src="http://www.espace-1789.com/sites/default/files/styles/mini_affiche/public/film_affiches/3854146.jpg-r_1920_1080-f_jpg-q_x-xxyxx.jpg?itok=IGz3hYrA" typeof="foaf:Image" width="135"/></a><div class="content-film"><a href="../film/ceux-qui-travaillent?semaine=4"><h4 class="film-spec"><span class="title">CEUX QUI TRAVAILLENT</span></h4></a><h5>Antoine Russbach </h5><ul class="seance-film"><li><em>mer. 09 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:30</span>16:30</span></div><div class="clear"></div></li><li><em>jeu. 10 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">17:50</span>17:50</span></div><div class="clear"></div></li><li><em>ven. 11 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:00</span>16:00</span></div><div class="clear"></div></li><li><em>sam. 12 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">18:10</span>18:10</span></div><div class="clear"></div></li><li><em>dim. 13 oct</em><div class="heures-seance-film"><span class="hour"><span class="tri">16:20</span>16:20</span><span class="hour"><span class="tri">20:50</span>20:50</span></div><div class="clear"></div></li></ul></div></li></ul></div>
# <div class="clear"></div>
# </div>
# </section>
# </div>
# </div>
# </div>
# </div> <!-- /#content -->
# </div> <!-- /#main-wrapper -->
# </div></div> <!-- /#page, /#page-wrapper -->
# <script src="/sites/all/themes/espace1789_responsive/js/script.js?1569059690"></script>
# <!-- <link rel="stylesheet" href="/sites/all/themes/espace1789_responsive/css/prettyPhoto.css" type="text/css" media="screen" title="prettyPhoto main stylesheet" />
# 		<script src="/sites/all/themes/espace1789_responsive/js/jquery.prettyPhoto.js"></script>-->
# </body>
# </html>

# %%
import re 

string = 'jeu. 22 aoû18:3018:3020:3020:30'
new = re.sub(r'\d\d:\d\d\d\d:\d\d', ' \g<0> ', string)
new
# Out:
# 'jeu. 22 aoû 18:3018:30  20:3020:30 '

# %%
content = response.find_all('li', {'class':'affiche-film-item'})

def get_title(movie):
    titles = movie.find('span', {'class':'title'})
    return(titles.text)

def get_actor(movie):
    actor_main = movie.find('h5') 
    return(actor_main.text)

def get_dates(movie):
    dates = movie.find_all('li')
    dates = [d.text for d in dates]
    new = [re.sub(r'\d\d:\d\d\d\d:\d\d', ' \g<0> ', date) for date in dates]
    new = [re.sub(r'\d\d:\d\d', ' \g<0>', date) for date in dates]
    new_dates = ", ".join(new)
    return(new_dates)

def get_data(content):  
    title = get_title(content)
    actor = get_actor(content)
    dates = get_dates(content)
    return {"title":title, "actor": actor, "dates": dates}

results = []
for c in content:
    results.append(get_data(c))

results
# Out:
# [{'title': 'LE DAIM ',
#   'actor': 'Quentin Dupieux ',
#   'dates': 'jeu. 19 sep 15:50 15:50, ven. 20 sep 19:00 19:00, dim. 22 sep 18:10 18:10, lun. 23 sep 20:20 20:20'},
#  {'title': 'MA FOLLE SEMAINE AVEC TESS',
#   'actor': 'De Steven Wouterlood ',
#   'dates': 'mer. 18 sep 10:00 10:00 14:40 14:40, dim. 22 sep 14:20 14:20 16:20 16:20, lun. 23 sep 18:30 18:30vo, mar. 24 sep 16:30 16:30vo'},
#  {'title': 'UN PETIT AIR DE FAMILLE ',
#   'actor': 'Collectif',
#   'dates': 'mer. 18 sep 10:30 10:30 16:40 16:40, dim. 22 sep 16:10 16:10'},
#  {'title': 'PORTRAIT DE LA JEUNE FILLE EN FEU ',
#   'actor': 'Céline Sciamma ',
#   'dates': 'mer. 18 sep 14:20 14:20 17:50 17:50 20:10 20:10, jeu. 19 sep 17:30 17:30 20:10 20:10, ven. 20 sep 14:10 14:10 16:40 16:40 21:00 21:00, dim. 22 sep 17:20 17:20 20:00 20:00rencontres, lun. 23 sep 14:00 14:00 16:10 16:10 18:10 18:10, mar. 24 sep 14:00 14:00 18:10 18:10 20:10 20:10'},
#  {'title': 'LES HIRONDELLES DE KABOUL',
#   'actor': 'Zabou Breitman et Eléa Gobbé-Mévellec',
#   'dates': 'mer. 18 sep 16:30 16:30 20:30 20:30, jeu. 19 sep 14:10 14:10 16:00 16:00, ven. 20 sep 17:00 17:00 19:10 19:10, dim. 22 sep 14:30 14:30 20:20 20:20, lun. 23 sep 12:00 12:00 20:30 20:30, mar. 24 sep 14:10 14:10 20:30 20:30'},
#  {'title': 'VIENDRA LE FEU ',
#   'actor': 'Oliver Laxe ',
#   'dates': 'mer. 18 sep 18:30 18:30, jeu. 19 sep 14:00 14:00 18:00 18:00, ven. 20 sep 21:10 21:10, lun. 23 sep 12:10 12:10 14:10 14:10 16:30 16:30, mar. 24 sep 16:20 16:20 18:30 18:30'},
#  {'title': 'SWEETIE',
#   'actor': 'Jane Campion ',
#   'dates': 'jeu. 19 sep 20:00 20:00vo'},
#  {'title': 'Retour vers le futur II',
#   'actor': 'Robert Zemeckis',
#   'dates': 'sam. 21 sep 15:00 15:00vf'},
#  {'title': 'FEMMES AU BORD DE LA CRISE DE NERFS',
#   'actor': 'Pedro Almodóvar ',
#   'dates': 'sam. 21 sep 15:10 15:10vo'},
#  {'title': 'INDIANA JONES ET LA DERNIÈRE CROISADE',
#   'actor': 'Steven Spielberg ',
#   'dates': 'sam. 21 sep 19:15 19:15vf 21:30 21:30vo'},
#  {'title': 'LES LIAISONS DANGEREUSES',
#   'actor': 'Stephen Frears ',
#   'dates': 'sam. 21 sep 21:00 21:00vo'},
#  {'title': 'RAIN MAN',
#   'actor': 'Barry Levinson ',
#   'dates': 'dim. 22 sep 00:00 00:00vo'},
#   'dates': 'mer. 02 oct 16:30 16:30 18:30 18:30, jeu. 03 oct 20:30 20:30, ven. 04 oct 17:40 17:40, sam. 05 oct 18:50 18:50 20:50 20:50, dim. 06 oct 14:30 14:30 20:20 20:20, lun. 07 oct 18:30 18:30, mar. 08 oct 16:10 16:10 20:10 20:10'},
#  {'title': 'DEMAIN EST A NOUS',
#   'actor': 'Gilles de Maistre ',
#   'dates': 'mer. 02 oct 10:00 10:00vf 14:30 14:30vf, jeu. 03 oct 18:40 18:40vo, sam. 05 oct 15:00 15:00vf 16:50 16:50vo, dim. 06 oct 16:30 16:30vf, lun. 07 oct 20:50 20:50vo, mar. 08 oct 18:10 18:10vo'},
#  {'title': 'BONJOUR LE MONDE ! ',
#   'actor': 'Anne–Lise Koehler, Eric Serre ',
#   'dates': 'mer. 02 oct 10:15 10:15 14:40 14:40 16:00 16:00, sam. 05 oct 15:20 15:20'},
#  {'title': 'CEUX QUI TRAVAILLENT',
#   'actor': 'Antoine Russbach ',
#   'dates': 'mer. 09 oct 16:30 16:30, jeu. 10 oct 17:50 17:50, ven. 11 oct 16:00 16:00, sam. 12 oct 18:10 18:10, dim. 13 oct 16:20 16:20 20:50 20:50'}]

# %%
import pandas as pd

movies = pd.DataFrame(results, columns=results[0].keys())
movies
# Out:
#                                     title  \
# 0                                LE DAIM
# 1              MA FOLLE SEMAINE AVEC TESS
# 2                UN PETIT AIR DE FAMILLE
# 3      PORTRAIT DE LA JEUNE FILLE EN FEU
# 4               LES HIRONDELLES DE KABOUL
# 5                         VIENDRA LE FEU
# 6                                 SWEETIE
# 7                 Retour vers le futur II
# 8     FEMMES AU BORD DE LA CRISE DE NERFS
# 9   INDIANA JONES ET LA DERNIÈRE CROISADE
# 10               LES LIAISONS DANGEREUSES
# 11                               RAIN MAN
# 12                 UN POISSON NOMMÉ WANDA
# 13             MA FOLLE SEMAINE AVEC TESS
# 14               UN PETIT AIR DE FAMILLE
# 15     PORTRAIT DE LA JEUNE FILLE EN FEU
# 16                               DEUX MOI
# 17                   LE MARIAGE DE VERIDA
# 18            UN JOUR DE PLUIE A NEW YORK
# 19            UN JOUR DE PLUIE A NEW YORK
# 20                   CEUX QUI TRAVAILLENT
# 21                         PORT AUTHORITY
# 22                      DEMAIN EST A NOUS
# 23                    BONJOUR LE MONDE !
# 24                   CEUX QUI TRAVAILLENT
#
#                                     actor  \
# 0                        Quentin Dupieux
# 1                   De Steven Wouterlood
# 2                               Collectif
# 3                         Céline Sciamma
# 4   Zabou Breitman et Eléa Gobbé-Mévellec
# 5                            Oliver Laxe
# 6                           Jane Campion
# 7                         Robert Zemeckis
# 8                        Pedro Almodóvar
# 9                       Steven Spielberg
# 10                        Stephen Frears
# 11                        Barry Levinson
# 12         Charles Crichton, John Cleese
# 13                  De Steven Wouterlood
# 14                              Collectif
# 15                        Céline Sciamma
# 16                       Cédric Klapisch
# 17                    Michela Occhipinti
# 18                           Woody Allen
# 19                           Woody Allen
# 20                      Antoine Russbach
# 21                    Danielle Lessovitz
# 22                     Gilles de Maistre
# 23         Anne–Lise Koehler, Eric Serre
# 24                      Antoine Russbach
#
#                                                 dates
# 0   jeu. 19 sep 15:50 15:50, ven. 20 sep 19:00 19:...
# 1   mer. 18 sep 10:00 10:00 14:40 14:40, dim. 22 s...
# 2   mer. 18 sep 10:30 10:30 16:40 16:40, dim. 22 s...
# 3   mer. 18 sep 14:20 14:20 17:50 17:50 20:10 20:1...
# 4   mer. 18 sep 16:30 16:30 20:30 20:30, jeu. 19 s...
# 5   mer. 18 sep 18:30 18:30, jeu. 19 sep 14:00 14:...
# 6                           jeu. 19 sep 20:00 20:00vo
# 7                           sam. 21 sep 15:00 15:00vf
# 8                           sam. 21 sep 15:10 15:10vo
# 9             sam. 21 sep 19:15 19:15vf 21:30 21:30vo
# 10                          sam. 21 sep 21:00 21:00vo
# 11                          dim. 22 sep 00:00 00:00vo
# 12                          dim. 22 sep 00:10 00:10vo
# 13  mer. 25 sep 10:00 10:00 14:20 14:20, sam. 28 s...
# 14   sam. 28 sep 17:00 17:00, dim. 29 sep 16:50 16:50
# 15  mer. 25 sep 18:20 18:20, jeu. 26 sep 18:00 18:...
# 16  mer. 25 sep 20:40 20:40, jeu. 26 sep 15:50 15:...
# 17  mer. 25 sep 16:10 16:10, ven. 27 sep 16:30 16:...
# 18  mer. 25 sep 18:20 18:20, jeu. 26 sep 18:00 18:...
# 19  mer. 02 oct 18:00 18:00 20:00 20:00, jeu. 03 o...
# 20  mer. 02 oct 20:30 20:30rencontres, jeu. 03 oct...
# 21  mer. 02 oct 16:30 16:30 18:30 18:30, jeu. 03 o...
# 22  mer. 02 oct 10:00 10:00vf 14:30 14:30vf, jeu. ...
# 23  mer. 02 oct 10:15 10:15 14:40 14:40 16:00 16:0...
# 24  mer. 09 oct 16:30 16:30, jeu. 10 oct 17:50 17:...

# %%
#Export csv:
movies.to_csv('../output/movies.csv', index=False)

# %%
#Other url:

url = 'https://www.vinted.fr/enfants/accessoires'
html = requests.get(url).content
response = BeautifulSoup()
response

# %%
#create a function for each item to find and then call one general function for all:

def get_title(bs4_tag):
    result = bs4_tag.find('img', {'class':'js-item-thumbnail item-thumbnail lazy-thumbnail __act_as_lazy'})
    result = result.get('alt')
    return(result)   
    
def get_brand(bs4_tag):
    result = bs4_tag.find("a", {"class":"item-box__brand"})
    if result == None:
        return "None"
    else:
        return(result.text)

def get_price(bs4_tag):
    result = bs4_tag.find("span")
    return(result.text)

def get_description(bs4_tag):
    result = bs4_tag.find("div", {"class":"media__placeholder"})
    return(result.text.replace('\n', ' '))    

def get_data(content):
    
    title = get_title(content)
    brand = get_brand(content)
    price = get_price(content)
    description = get_description(content)
    
    return {"title":title, "price": price, "brand": brand, "description": description}

# %%
#Add pagination to scrap several pages:

results = []
for i in range(10):
    url = "https://www.vinted.fr/enfants/accessoires?page={i}"
    r = requests.get(url).content
    response = BeautifulSoup(html, "lxml")
    contents = response.find_all('div', {'class':'is-visible item-box__container'})
    for content in contents:
        results.append(get_data(content))
      
results
# Out:
# [{'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '},
#  {'title': 'Gants Lacoste enfant Neufs 6-8 ans ',
#   'price': '16,00 €',
#   'brand': 'Lacoste',
#   'description': '   Lacoste             Gants LACOSTE  Tout NEUFS  Erreur de taille malheureusement, c’est pour cela que je les vends ... ils sont magnifiques.                '},
#  {'title': 'Mouffles fourrées 12 à 24 mois état neuf',
#   'price': '2,00 €',
#   'brand': 'None',
#   'description': '             Bien chaudes              '},
#  {'title': 'Gants imperméables bébé ',
#   'price': '3,00 €',
#   'brand': 'H&M',
#   'description': '   H&M             moufles pour la main entière  taille 2 à 6 mois h et m  neuves               '},
#  {'title': 'Casquette adidas bleue',
#   'price': '6,00 €',
#   'brand': 'Adidas',
#   'description': '   Adidas             Portée une fois              '},
#  {'title': 'Bonnet Disney Jack le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur gris et blanc  Taille 52  Neuf                '},
#  {'title': 'Bonnet Natalys',
#   'price': '2,00 €',
#   'brand': 'natalys',
#   'description': '   natalys             bon état général  Taille 2  pour enfant de 2 ans               '},
#  {'title': 'Casquette hello kitty, 54',
#   'price': '2,00 €',
#   'brand': 'Hello Kitty',
#   'description': '   Hello Kitty             Blanche et bleue, taille 54              '},
#  {'title': 'Gorritos de algodón nuevos de h&m',
#   'price': '1,50 €',
#   'brand': 'H&M',
#   'description': '   H&M             Están nuevos con etiqueta. Primera puesta              '},
#  {'title': 'Uv pet',
#   'price': '1,00 €',
#   'brand': 'Hema',
#   'description': '   Hema             Ongedragen, maat 86/92              '},
#  {'title': 'Lot de 2 ceintures ado',
#   'price': '6,00 €',
#   'brand': 'Kaporal',
#   'description': '   Kaporal             Très bon état                '},
#  {'title': 'Gants Kenny ',
#   'price': '15,00 €',
#   'brand': 'None',
#   'description': '             Vends gants de la marque Kenny état neuf, noirs, taille 3, idéal petites mains ! Utilisé pour faire du BMX              '},
#  {'title': 'Gorra Fox ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             Usado muy pocas veces,  color negro y naranja.               '},
#  {'title': 'Casquette DPAM rouge',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Casquette DPAM rouge  0-3 mois               '},
#  {'title': 'Bonnet de bain neuf',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Utilisé une seule fois. Taille unique.              '},
#  {'title': 'Bonnet Disney Jake le pirate',
#   'price': '6,00 €',
#   'brand': 'Disney',
#   'description': '   Disney             Au top pour l hiver 💟  Bonnet Disney Jack le pirate  Couleur marine  Taille 54  Neuf              '},
#  {'title': 'Gorra FOX ',
#   'price': '6,00 €',
#   'brand': 'Fox',
#   'description': '   Fox             En buen estado. Negra  Talla Niño para 4-5 años               '},
#  {'title': 'Bonnet beige',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bonnet beige              '},
#  {'title': 'Bonnet en laine Benetton enfant 10-12 ans',
#   'price': '5,00 €',
#   'brand': 'United Colors of Benetton',
#   'description': '   United Colors of Benetton             Neuf sans étiquette . article jamais porté .  Bleu clair .               '},
#  {'title': 'Chapka grise 3 mois Obaïbi',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Chapka Grise 3 mois Obaïbi              '},
#  {'title': 'Bonnet noir reebok enfant 10 12 ans ',
#   'price': '1,50 €',
#   'brand': 'Reebok',
#   'description': '   Reebok             Porté. Quelques peluches.              '},
#  {'title': 'Bretelles noires',
#   'price': '1,00 €',
#   'brand': 'None',
#   'description': '             Bretelles noires portées 2 ou 4 fois              '},
#  {'title': 'Gants de ski enfant 4 ans ',
#   'price': '3,50 €',
#   'brand': 'Go sport',
#   'description': '   Go sport             très bon état               '},
#  {'title': 'Casquette hiver neuve ',
#   'price': '4,50 €',
#   'brand': 'okaïdi',
#   'description': '   okaïdi             Très jolie Casquette hiver neuve avec patch  Touché tout doux  Tour de taille 43cm équivaut à 3 mois  Okaidi               '},
#  {'title': 'Bonnet petit bateau T45cm',
#   'price': '6,00 €',
#   'brand': 'Petit Bateau',
#   'description': '   Petit Bateau             bonnet coton indiqué 67cm mais erreur taille correspond 45cm               '}]

# %%
#Create a pandas dataframe:

import pandas as pd

df = pd.DataFrame(results, columns=results[0].keys())
df
# Out:
#                                          title    price  \
# 0          Gants Lacoste enfant Neufs 6-8 ans   16,00 €
# 1     Mouffles fourrées 12 à 24 mois état neuf   2,00 €
# 2                     Gants imperméables bébé    3,00 €
# 3                       Casquette adidas bleue   6,00 €
# 4                 Bonnet Disney Jack le pirate   6,00 €
# 5                               Bonnet Natalys   2,00 €
# 6                    Casquette hello kitty, 54   2,00 €
# 7            Gorritos de algodón nuevos de h&m   1,50 €
# 8                                       Uv pet   1,00 €
# 9                       Lot de 2 ceintures ado   6,00 €
# 10                                Gants Kenny   15,00 €
# 11                                  Gorra Fox    6,00 €
# 12                        Casquette DPAM rouge   1,00 €
# 13                         Bonnet de bain neuf   1,00 €
# 14                Bonnet Disney Jake le pirate   6,00 €
# 15                                  Gorra FOX    6,00 €
# 16                                Bonnet beige   1,00 €
# 224                       Hema
# 225                    Kaporal
# 226                       None
# 227                        Fox
# 228                       None
# 229                       None
# 230                     Disney
# 231                        Fox
# 232                       None
# 233  United Colors of Benetton
# 234                       None
# 235                     Reebok
# 236                       None
# 237                   Go sport
# 238                     okaïdi
# 239               Petit Bateau
#
#                                            description
# 0       Lacoste             Gants LACOSTE  Tout NEU...
# 1                           Bien chaudes
# 2       H&M             moufles pour la main entièr...
# 3       Adidas             Portée une fois         ...
# 4       Disney             Au top pour l hiver 💟  B...
# 5       natalys             bon état général  Taill...
# 6       Hello Kitty             Blanche et bleue, t...
# 7       H&M             Están nuevos con etiqueta. ...
# 8       Hema             Ongedragen, maat 86/92    ...
# 9       Kaporal             Très bon état          ...
# 10                Vends gants de la marque Kenny ét...
# 11      Fox             Usado muy pocas veces,  col...
# 12                Casquette DPAM rouge  0-3 mois   ...
# 13                Utilisé une seule fois. Taille un...
# 14      Disney             Au top pour l hiver 💟  B...
# 15      Fox             En buen estado. Negra  Tall...
# 16                          Bonnet beige
# 17      United Colors of Benetton             Neuf ...
# 18                Chapka Grise 3 mois Obaïbi       ...
# 19      Reebok             Porté. Quelques peluches...
# 20                Bretelles noires portées 2 ou 4 f...
# 21      Go sport             très bon état         ...
# 22      okaïdi             Très jolie Casquette hiv...
# 23      Petit Bateau             bonnet coton indiq...
# 24      Lacoste             Gants LACOSTE  Tout NEU...
# 25                          Bien chaudes
# 26      H&M             moufles pour la main entièr...
# 27      Adidas             Portée une fois         ...
# 28      Disney             Au top pour l hiver 💟  B...
# 29      natalys             bon état général  Taill...
# ..                                                 ...
# 210               Chapka Grise 3 mois Obaïbi       ...
# 211     Reebok             Porté. Quelques peluches...
# 212               Bretelles noires portées 2 ou 4 f...
# 213     Go sport             très bon état         ...
# 214     okaïdi             Très jolie Casquette hiv...
# 215     Petit Bateau             bonnet coton indiq...
# 216     Lacoste             Gants LACOSTE  Tout NEU...
# 217                         Bien chaudes
# 218     H&M             moufles pour la main entièr...
# 219     Adidas             Portée une fois         ...
# 220     Disney             Au top pour l hiver 💟  B...
# 221     natalys             bon état général  Taill...
# 222     Hello Kitty             Blanche et bleue, t...
# 223     H&M             Están nuevos con etiqueta. ...
# 224     Hema             Ongedragen, maat 86/92    ...
# 225     Kaporal             Très bon état          ...
# 226               Vends gants de la marque Kenny ét...
# 227     Fox             Usado muy pocas veces,  col...
# 228               Casquette DPAM rouge  0-3 mois   ...
# 229               Utilisé une seule fois. Taille un...
# 230     Disney             Au top pour l hiver 💟  B...
# 231     Fox             En buen estado. Negra  Tall...
# 232                         Bonnet beige
# 233     United Colors of Benetton             Neuf ...
# 234               Chapka Grise 3 mois Obaïbi       ...
# 235     Reebok             Porté. Quelques peluches...
# 236               Bretelles noires portées 2 ou 4 f...
# 237     Go sport             très bon état         ...
# 238     okaïdi             Très jolie Casquette hiv...
# 239     Petit Bateau             bonnet coton indiq...
#
# [240 rows x 4 columns]

# %%
#Export csv:
df.to_csv('../output/vinted.csv', index=False)
