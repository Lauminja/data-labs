# %% [markdown]
# # Guided Project: Web Data Pipeline

# %% [markdown]
# Goal: practice what you have learned in the Intermediate Python and Data Engineering chapter
#
# Get Started:
#
# * Find a data set to process - You can use a dataset you are familiar with like
#   https://www.kaggle.com/teajay/global-shark-attacks/version/1 or find another.
#   A great place to start looking would be https://github.com/awesomedata/awesome-public-datasets
#   and https://www.kaggle.com/datasets.
# * Examine the data and come up with a deliverable before diving in and applying any methods to it.
# * You will need to import it, use your newly-acquired skills to build a data pipeline that processes the data
#   and produces a result.
# * You must construct a data pipeline with the majority of your code wrapped in functions.
# * Break the project down into different steps - leverage the stages of the data pipeline covered in the pipelines
#   lesson and answer the appropriate questions for each stage.
# * Each data pipeline stage should be covered: acquisition, wrangling, analysis, and reporting.
# * You must demonstrate all the topics we covered in the chapter (functions, list comprehensions, string operations, and error handling) in your processing of the data.
# * Your code should be saved in a Python executable file (.py), your data should be saved in a folder named data, and your results should be saved in a folder named output.
# * You should also include a README.md file that describes the steps you took and your thought process as you built your data pipeline.

# %%
import pandas as pd
import numpy as np

# %%
products = pd.read_csv('/Users/laumaustupa/Desktop/Ironhack/Cours/data-labs/module-1/pipelines-project/data/DatafinitiElectronicsProductsPricingData.csv', encoding='latin1')
products
# Out:
#                         id  prices.amountMax  prices.amountMin  \
# 0     AVphzgbJLJeJML43fA0o            104.99            104.99
# 1     AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2     AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3     AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4     AVpgMuGwLJeJML43KY_c             66.99             66.99
# 5     AVpgMuGwLJeJML43KY_c             66.00             66.00
# 6     AVpgMuGwLJeJML43KY_c             74.99             74.99
# 7     AVpgMuGwLJeJML43KY_c             65.99             65.99
# 8     AVpgMuGwLJeJML43KY_c             69.99             69.99
# 9     AVpgMuGwLJeJML43KY_c             69.00             64.00
# 10    AVpgMuGwLJeJML43KY_c             69.99             69.99
# 11    AVpgMuGwLJeJML43KY_c             64.99             64.99
# 12    AVpgMuGwLJeJML43KY_c             64.99             64.99
# 13    AVpe9FXeLJeJML43zHrq             23.99             23.99
# 14    AVpe9FXeLJeJML43zHrq             31.99             31.99
# 15    AVpe9FXeLJeJML43zHrq             20.99             20.99
# 16    AVpe9FXeLJeJML43zHrq             34.99             34.99
# 17    AVpe9FXeLJeJML43zHrq             23.99             23.99
# 18    AVpfVJXu1cnluZ0-iwTT            290.99            290.99
# 19    AVpfVJXu1cnluZ0-iwTT            279.99            279.99
# 20    AVpfVJXu1cnluZ0-iwTT            299.99            299.99
# 21    AVpfVJXu1cnluZ0-iwTT            225.99            225.99
# 22    AVpfVJXu1cnluZ0-iwTT            289.99            289.99
# 23    AVphUeKeilAPnD_x3-Be            244.01            244.01
# 24    AVphUeKeilAPnD_x3-Be            132.99            132.99
# 25    AVphUeKeilAPnD_x3-Be            149.99            149.99
# 26    AVphUeKeilAPnD_x3-Be            149.95            149.95
# 27    AVphUeKeilAPnD_x3-Be            136.99            136.99
# 28    AVpi6aLv1cnluZ0-Rv8A            254.99            254.99
# 29    AVpi6aLv1cnluZ0-Rv8A            209.99            209.99
# ...                    ...               ...               ...
# 3470  AVqVGUFCv8e3D1O-ldFF           5199.99           2997.99
# 3471  AVqVGUFCv8e3D1O-ldFF           2297.99           2297.99
# 3472  AVqVGUFCv8e3D1O-ldFF           5199.99           2797.99
# 3473  AVqVGUFCv8e3D1O-ldFF           3899.99           3899.99
# 3474  AVqVGUFCv8e3D1O-ldFF           5199.99           2897.99
# 3475  AVqVGUFCv8e3D1O-ldFF           5199.99           2297.99
# 3476  AVqVGUFCv8e3D1O-ldFF           4297.99           2497.99
# 3477  AVqVGUFCv8e3D1O-ldFF           4297.99           2897.99
# 3478  AVqVGUFCv8e3D1O-ldFF           4297.99           2597.99
# 3479  AVqVGUFCv8e3D1O-ldFF           4297.99           2997.99
# 3480  AVqVGUFCv8e3D1O-ldFF           2297.99           2297.99
# 3481  AVqVGUFCv8e3D1O-ldFF           5199.99           2597.99
# 3482  AVqVGUFCv8e3D1O-ldFF           2398.95           2398.95
# 3483  AVqVGUFCv8e3D1O-ldFF           2999.99           2999.99
# 3484  AVqVGUFCv8e3D1O-ldFF           2897.99           2897.99
# 3485  AVqVGUFCv8e3D1O-ldFF           4297.99           2797.99
# 3486  AVqVGUFCv8e3D1O-ldFF           3096.95           3096.95
# 3487  AVqVGUFCv8e3D1O-ldFF           3097.95           3097.95
# 3488  AVqVGUFCv8e3D1O-ldFF           5199.99           1999.99
# 3489  AVqVGUFCv8e3D1O-ldFF           3136.95           3136.95
# 3490  AVqVGUFCv8e3D1O-ldFF           4297.99           3195.98
# 3491  AVqVGUFCv8e3D1O-ldFF           4297.99           2875.98
# 3492  AVqVGUFCv8e3D1O-ldFF           3137.95           3137.95
# 3493  AVpf7PsHilAPnD_xkn6H           1099.99           1099.99
# 3494  AVpf7PsHilAPnD_xkn6H            999.99            999.99
# 3495  AVpf7PsHilAPnD_xkn6H            944.96            944.96
# 3496  AVpf7PsHilAPnD_xkn6H            909.99            909.99
# 3497  AVpf7PsHilAPnD_xkn6H              1.00              1.00
# 3498  AVpf7PsHilAPnD_xkn6H            759.99            759.99
# 3499  AVpf7PsHilAPnD_xkn6H           1122.62            842.62
#
#      prices.availability         prices.condition prices.currency  \
# 0                    Yes                      New             USD
# 1               In Stock                      New             USD
# 2               In Stock                      New             USD
# 3                    Yes                      New             USD
# 4                    Yes                      New             USD
# 5               In Stock                      New             USD
# 6               In Stock                      New             USD
# 7                    Yes                      New             USD
# 8               In Stock                      New             USD
# 9               In Stock                      New             USD
# 10                  TRUE                      new             USD
# 11              In Stock                      New             USD
# 12                   Yes                      New             USD
# 13                  TRUE                      new             USD
# 14                  TRUE                      new             USD
# 15                   Yes                      New             USD
# 16                  TRUE                      new             USD
# 17                   Yes                      New             USD
# 18                   Yes                      New             USD
# 19                   Yes                      New             USD
# 20                  TRUE                      new             USD
# 21                  TRUE                      new             USD
# 22                   Yes                      New             USD
# 23              In Stock                      New             USD
# 24                   Yes                      New             USD
# 25                   Yes                      New             USD
# 26              In Stock                      New             USD
# 27                   Yes                      New             USD
# 28                   Yes                      New             USD
# 29                   Yes                      New             USD
# ...                  ...                      ...             ...
# 3470            In Stock                      New             USD
# 3471            In Stock                      New             USD
# 3472            In Stock                      New             USD
# 3473                 Yes                      New             USD
# 3474            In Stock                      New             USD
# 3475            In Stock                      New             USD
# 3476            In Stock                      New             USD
# 3477            In Stock                      New             USD
# 3478            In Stock                      New             USD
# 3479            In Stock                      New             USD
# 3480            In Stock                      New             USD
# 3481            In Stock                      New             USD
# 3482                 yes                      New             USD
# 3483                 Yes                      New             USD
# 3484            In Stock                      New             USD
# 3485            In Stock                      New             USD
# 3486                 yes                      New             USD
# 3487                 yes                      New             USD
# 3488            In Stock                      New             USD
# 3489                 yes                      New             USD
# 3490            In Stock                      New             USD
# 3491            In Stock                      New             USD
# 3492                 yes                      New             USD
# 3493                 Yes                      New             USD
# 3494            In Stock                      New             USD
# 3495                 yes  New other (see details)             USD
# 3496                 Yes                      New             USD
# 3497                 Yes                      New             USD
# 3498                 Yes                      New             USD
# 3499            In Stock                      New             USD
#
#                                         prices.dateSeen  prices.isSale  \
# 0     2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                                  2017-12-14T06:00:00Z           True
# 2                                  2017-09-08T05:00:00Z          False
# 3                                  2017-10-10T05:00:00Z          False
# 4                                  2017-08-28T07:00:00Z          False
# 5                                  2017-10-24T04:00:00Z          False
# 6                                  2017-08-15T15:00:00Z          False
# 7                                  2017-08-12T09:00:00Z          False
# 8                                  2017-09-14T21:00:00Z          False
# 9                                  2018-01-21T08:00:00Z           True
# 10                                 2018-05-26T07:00:00Z          False
# 11                                 2017-07-23T00:00:00Z          False
# 12    2017-08-01T03:00:00Z,2017-07-26T15:00:00Z,2017...          False
# 13                                 2018-05-26T16:00:00Z          False
# 14                                 2015-03-25T22:00:00Z          False
# 15                                 2014-10-27T00:00:00Z           True
# 16                                 2015-04-23T09:00:00Z          False
# 17    2017-10-10T12:00:00Z,2017-09-12T05:00:00Z,2017...          False
# 18    2017-08-01T00:00:00Z,2017-08-01T17:00:00Z,2017...          False
# 19            2017-06-01T17:00:00Z,2017-06-01T19:00:00Z          False
# 20                                 2018-05-26T06:00:00Z          False
# 21                                 2018-05-26T06:00:00Z           True
# 22    2017-10-10T20:00:00Z,2017-09-18T13:00:00Z,2017...          False
# 23                                 2018-01-18T12:00:00Z          False
# 24                                 2015-07-02T05:00:00Z           True
# 25    2017-10-10T19:00:00Z,2017-09-06T17:00:00Z,2017...          False
# 26    2018-07-25T22:00:00Z,2017-12-06T21:00:00Z,2017...           True
# 27                                 2015-03-10T19:00:00Z           True
# 28            2017-03-10T22:00:00Z,2017-03-04T10:00:00Z           True
# 29                                 2017-03-30T06:00:00Z           True
# ...                                                 ...            ...
# 3470  2017-07-21T16:00:00Z,2017-07-21T14:00:00Z,2017...           True
# 3471                               2017-12-06T01:00:00Z          False
# 3472          2017-10-28T17:00:00Z,2017-10-24T22:00:00Z           True
# 3473          2017-05-09T03:00:00Z,2017-05-18T02:00:00Z          False
# 3474  2017-09-15T00:00:00Z,2017-09-07T14:00:00Z,2017...           True
# 3475                               2018-03-09T18:00:00Z           True
# 3476          2018-04-26T17:00:00Z,2018-03-09T18:00:00Z           True
# 3477                               2017-09-17T08:00:00Z           True
# 3478          2017-11-08T20:00:00Z,2017-10-28T18:00:00Z           True
# 3479                               2017-07-23T02:00:00Z           True
# 3480  2018-04-26T17:00:00Z,2017-12-07T23:00:00Z,2017...           True
# 3481                               2017-11-16T19:00:00Z           True
# 3482                               2017-08-24T18:00:00Z          False
# 3483          2017-08-01T03:00:00Z,2017-07-26T15:00:00Z          False
# 3484  2017-09-22T10:00:00Z,2017-08-22T10:00:00Z,2017...           True
# 3485                               2017-10-24T22:00:00Z           True
# 3486                               2017-06-20T23:00:00Z          False
# 3487                               2017-06-18T15:00:00Z          False
# 3488                               2018-04-26T17:00:00Z           True
# 3489                               2017-06-15T17:00:00Z          False
# 3490                               2017-10-24T22:00:00Z           True
# 3491                               2017-11-08T20:00:00Z           True
# 3492                               2017-06-10T11:00:00Z          False
# 3493  2017-05-09T07:00:00Z,2017-05-01T20:00:00Z,2017...          False
# 3494  2017-08-19T05:00:00Z,2017-08-22T04:00:00Z,2018...          False
# 3495                               2017-06-22T15:00:00Z          False
# 3496                               2017-03-10T19:00:00Z           True
# 3497                               2017-03-04T10:00:00Z           True
# 3498                               2017-03-30T05:00:00Z           True
# 3499                               2017-08-14T14:00:00Z           True
#
#              prices.merchant  \
# 0                Bestbuy.com
# 1                Walmart.com
# 2                Walmart.com
# 3                Bestbuy.com
# 4                Bestbuy.com
# 5                Walmart.com
# 6     California Electronics
# 7                Bestbuy.com
# 8                Walmart.com
# 9                Walmart.com
# 10               Bestbuy.com
# 11               Walmart.com
# 12               Bestbuy.com
# 13               Bestbuy.com
# 14     Wayfair - Walmart.com
# 15               Bestbuy.com
# 16     Wayfair - Walmart.com
# 17               Bestbuy.com
# 18               Bestbuy.com
# 19               Bestbuy.com
# 20               Bestbuy.com
# 21               Bestbuy.com
# 22               Bestbuy.com
# 23                  Growkart
# 24               Bestbuy.com
# 25               Bestbuy.com
# 26          bhphotovideo.com
# 27               Bestbuy.com
# 28               Bestbuy.com
# 29               Bestbuy.com
# ...                      ...
# 3470             Walmart.com
# 3471                 OneCall
# 3472             Walmart.com
# 3473             Bestbuy.com
# 3474             Walmart.com
# 3475             Walmart.com
# 3476            Beach Camera
# 3477            Beach Camera
# 3478            Beach Camera
# 3479            Beach Camera
# 3480        bhphotovideo.com
# 3481             Walmart.com
# 3482               gear4less
# 3483             Bestbuy.com
# 3484        bhphotovideo.com
# 3485            Beach Camera
# 3486               gear4less
# 3487               gear4less
# 3488             Walmart.com
# 3489               gear4less
# 3490            Beach Camera
# 3491            Beach Camera
# 3492               gear4less
# 3493             Bestbuy.com
# 3494        bhphotovideo.com
# 3495                tfldealz
# 3496             Bestbuy.com
# 3497             Bestbuy.com
# 3498             Bestbuy.com
# 3499           Monoprice Inc
#
#                                        prices.shipping  ...  \
# 0                                                  NaN  ...
# 1                                            Expedited  ...
# 2                                            Expedited  ...
# 3                                                  NaN  ...
# 4                                                  NaN  ...
# 5                                            Expedited  ...
# 6                                                Value  ...
# 7                                                  NaN  ...
# 8                                            Expedited  ...
# 9                                             Standard  ...
# 10                                                 NaN  ...
# 11                                           Expedited  ...
# 12                                                 NaN  ...
# 13                                                 NaN  ...
# 14                                                 NaN  ...
# 15                                       Free Shipping  ...
# 16                                                 NaN  ...
# 17                                                 NaN  ...
# 18                                                 NaN  ...
# 19                                                 NaN  ...
# 20                                                 NaN  ...
# 21                                                 NaN  ...
# 22                                                 NaN  ...
# 23                                               Value  ...
# 24                    Free Shippingon orders 35 and up  ...
# 25                                                 NaN  ...
# 26                             Free Expedited Shipping  ...
# 27                   Free Shipping on orders 35 and up  ...
# 28                                                 NaN  ...
# 29                                                 NaN  ...
# ...                                                ...  ...
# 3470                                           Freight  ...
# 3471                                           Freight  ...
# 3472                                           Freight  ...
# 3473                                     Free Delivery  ...
# 3474                                           Freight  ...
# 3475                                          Standard  ...
# 3476                                          Standard  ...
# 3477                                             Value  ...
# 3478                                             Value  ...
# 3479                                          Standard  ...
# 3480  Free Expedited Shipping for most orders over $49  ...
# 3481                                           Freight  ...
# 3482                                              FREE  ...
# 3483                                     Free Delivery  ...
# 3484  Free Expedited Shipping for most orders over $49  ...
# 3485                                             Value  ...
# 3486                                              FREE  ...
# 3487                                              FREE  ...
# 3488                                          Standard  ...
# 3489                                               NaN  ...
# 3490                                             Value  ...
# 3491                                             Value  ...
# 3492                                              FREE  ...
# 3493                                     Free Delivery  ...
# 3494                            Shipping Charges Apply  ...
# 3495                                              FREE  ...
# 3496                                     Free Delivery  ...
# 3497                                     Free Delivery  ...
# 3498                                     Free Delivery  ...
# 3499                                          Standard  ...
#
#                                                    name primaryCategories  \
# 0     Sanus VLF410B1 10-Inch Super Slim Full-Motion ...       Electronics
# 1     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 2     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 3     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 4     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 5     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 6     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 7     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 8     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 9     Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 10    Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 11    Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 12    Boytone - 2500W 2.1-Ch. Home Theater System - ...       Electronics
# 13    DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...       Electronics
# 14    DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...       Electronics
# 15    DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...       Electronics
# 16    DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...       Electronics
# 17    DENAQ - AC Adapter for TOSHIBA SATELLITE 1700 ...       Electronics
# 18    DreamWave - Tremor Portable Bluetooth Speaker ...       Electronics
# 19    DreamWave - Tremor Portable Bluetooth Speaker ...       Electronics
# 20    DreamWave - Tremor Portable Bluetooth Speaker ...       Electronics
# 21    DreamWave - Tremor Portable Bluetooth Speaker ...       Electronics
# 22    DreamWave - Tremor Portable Bluetooth Speaker ...       Electronics
# 23    NS-SP1800BL 5.1-Channel Home Theater System (B...       Electronics
# 24    NS-SP1800BL 5.1-Channel Home Theater System (B...       Electronics
# 25    NS-SP1800BL 5.1-Channel Home Theater System (B...       Electronics
# 26    NS-SP1800BL 5.1-Channel Home Theater System (B...       Electronics
# 27    NS-SP1800BL 5.1-Channel Home Theater System (B...       Electronics
# 28    Universal Remote Control - 48-Device Universal...       Electronics
# 29    Universal Remote Control - 48-Device Universal...       Electronics
# ...                                                 ...               ...
# 3470  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3471  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3472  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3473  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3474  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3475  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3476  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3477  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3478  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3479  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3480  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3481  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3482  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3483  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3484  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3485  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3486  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3487  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3488  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3489  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3490  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3491  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3492  Refurbished Samsung Curved 65 4K (2160P) Smart...       Electronics
# 3493  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3494  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3495  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3496  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3497  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3498  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
# 3499  P-Series 55-Class UHD SmartCast LED Home Theat...       Electronics
#
#                                              sourceURLs          upc  \
# 0     https://www.amazon.com/Sanus-VLF410B1-10-Inch-...  7.93796E+11
# 1     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 2     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 3     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 4     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 5     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 6     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 7     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 8     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 9     http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 10    http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 11    http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 12    http://reviews.bestbuy.com/3545/4784804/review...  6.42015E+11
# 13    http://www.bestbuy.com/site/denaq-ac-adapter-f...  8.14352E+11
# 14    http://www.bestbuy.com/site/denaq-ac-adapter-f...  8.14352E+11
# 15    http://www.bestbuy.com/site/denaq-ac-adapter-f...  8.14352E+11
# 16    http://www.bestbuy.com/site/denaq-ac-adapter-f...  8.14352E+11
# 17    http://www.bestbuy.com/site/denaq-ac-adapter-f...  8.14352E+11
# 18    https://www.bestbuy.com/site/dreamwave-tremor-...  7.52424E+11
# 19    https://www.bestbuy.com/site/dreamwave-tremor-...  7.52424E+11
# 20    https://www.bestbuy.com/site/dreamwave-tremor-...  7.52424E+11
# 21    https://www.bestbuy.com/site/dreamwave-tremor-...  7.52424E+11
# 22    https://www.bestbuy.com/site/dreamwave-tremor-...  7.52424E+11
# 23    http://reviews.homedepot.com/1999m/203655164/r...  27108105321
# 24    http://reviews.homedepot.com/1999m/203655164/r...  27108105321
# 25    http://reviews.homedepot.com/1999m/203655164/r...  27108105321
# 26    http://reviews.homedepot.com/1999m/203655164/r...  27108105321
# 27    http://reviews.homedepot.com/1999m/203655164/r...  27108105321
# 28    https://reviews.bestbuy.com/3545/8381044/revie...  6.56787E+11
# 29    https://reviews.bestbuy.com/3545/8381044/revie...  6.56787E+11
# ...                                                 ...          ...
# 3470  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3471  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3472  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3473  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3474  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3475  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3476  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3477  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3478  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3479  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3480  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3481  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3482  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3483  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3484  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3485  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3486  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3487  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3488  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3489  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3490  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3491  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3492  https://www.bhphotovideo.com/c/product/1320393...  8.41434E+11
# 3493  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3494  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3495  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3496  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3497  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3498  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
# 3499  https://www.bhphotovideo.com/c/product/8015654...  8.45226E+11
#
#                             weight Unnamed: 26 Unnamed: 27 Unnamed: 28  \
# 0                      32.8 pounds         NaN         NaN         NaN
# 1                        14 pounds         NaN         NaN         NaN
# 2                        14 pounds         NaN         NaN         NaN
# 3                        14 pounds         NaN         NaN         NaN
# 4                        14 pounds         NaN         NaN         NaN
# 5                        14 pounds         NaN         NaN         NaN
# 6                        14 pounds         NaN         NaN         NaN
# 7                        14 pounds         NaN         NaN         NaN
# 8                        14 pounds         NaN         NaN         NaN
# 9                        14 pounds         NaN         NaN         NaN
# 10                       14 pounds         NaN         NaN         NaN
# 11                       14 pounds         NaN         NaN         NaN
# 12                       14 pounds         NaN         NaN         NaN
# 13                      1.2 pounds         NaN         NaN         NaN
# 14                      1.2 pounds         NaN         NaN         NaN
# 15                      1.2 pounds         NaN         NaN         NaN
# 16                      1.2 pounds         NaN         NaN         NaN
# 17                      1.2 pounds         NaN         NaN         NaN
# 18                     13.2 pounds         NaN         NaN         NaN
# 19                     13.2 pounds         NaN         NaN         NaN
# 20                     13.2 pounds         NaN         NaN         NaN
# 21                     13.2 pounds         NaN         NaN         NaN
# 22                     13.2 pounds         NaN         NaN         NaN
# 23    1.6 lb 2.6 lb 1.6 lb 18.7 lb         NaN         NaN         NaN
# 24    1.6 lb 2.6 lb 1.6 lb 18.7 lb         NaN         NaN         NaN
# 25    1.6 lb 2.6 lb 1.6 lb 18.7 lb         NaN         NaN         NaN
# 26    1.6 lb 2.6 lb 1.6 lb 18.7 lb         NaN         NaN         NaN
# 27    1.6 lb 2.6 lb 1.6 lb 18.7 lb         NaN         NaN         NaN
# 28                      1.1 pounds         NaN         NaN         NaN
# 29                      1.1 pounds         NaN         NaN         NaN
# ...                            ...         ...         ...         ...
# 3470                       54.2 lb         NaN         NaN         NaN
# 3471                       54.2 lb         NaN         NaN         NaN
# 3472                       54.2 lb         NaN         NaN         NaN
# 3473                       54.2 lb         NaN         NaN         NaN
# 3474                       54.2 lb         NaN         NaN         NaN
# 3475                       54.2 lb         NaN         NaN         NaN
# 3476                       54.2 lb         NaN         NaN         NaN
# 3477                       54.2 lb         NaN         NaN         NaN
# 3478                       54.2 lb         NaN         NaN         NaN
# 3479                       54.2 lb         NaN         NaN         NaN
# 3480                       54.2 lb         NaN         NaN         NaN
# 3481                       54.2 lb         NaN         NaN         NaN
# 3482                       54.2 lb         NaN         NaN         NaN
# 3483                       54.2 lb         NaN         NaN         NaN
# 3484                       54.2 lb         NaN         NaN         NaN
# 3485                       54.2 lb         NaN         NaN         NaN
# 3486                       54.2 lb         NaN         NaN         NaN
# 3487                       54.2 lb         NaN         NaN         NaN
# 3488                       54.2 lb         NaN         NaN         NaN
# 3489                       54.2 lb         NaN         NaN         NaN
# 3490                       54.2 lb         NaN         NaN         NaN
# 3491                       54.2 lb         NaN         NaN         NaN
# 3492                       54.2 lb         NaN         NaN         NaN
# 3493                      41.01 lb         NaN         NaN         NaN
# 3494                      41.01 lb         NaN         NaN         NaN
# 3495                      41.01 lb         NaN         NaN         NaN
# 3496                      41.01 lb         NaN         NaN         NaN
# 3497                      41.01 lb         NaN         NaN         NaN
# 3498                      41.01 lb         NaN         NaN         NaN
# 3499                      41.01 lb         NaN         NaN         NaN
#
#      Unnamed: 29 Unnamed: 30
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# ...          ...         ...
# 3470         NaN         NaN
# 3471         NaN         NaN
# 3472         NaN         NaN
# 3473         NaN         NaN
# 3474         NaN         NaN
# 3475         NaN         NaN
# 3476         NaN         NaN
# 3477         NaN         NaN
# 3478         NaN         NaN
# 3479         NaN         NaN
# 3480         NaN         NaN
# 3481         NaN         NaN
# 3482         NaN         NaN
# 3483         NaN         NaN
# 3484         NaN         NaN
# 3485         NaN         NaN
# 3486         NaN         NaN
# 3487         NaN         NaN
# 3488         NaN         NaN
# 3489         NaN         NaN
# 3490         NaN         NaN
# 3491         NaN         NaN
# 3492         NaN         NaN
# 3493         NaN         NaN
# 3494         NaN         NaN
# 3495         NaN         NaN
# 3496         NaN         NaN
# 3497         NaN         NaN
# 3498         NaN         NaN
# 3499         NaN         NaN
#
# [3500 rows x 31 columns]

# %%
#Remove duplicate rows:
before = len(products)
products = products.drop_duplicates()
after = len(products)

print('Number of duplicate records dropped: ', str(before - after))
# Out:
# Number of duplicate records dropped:  0

# %%
#Row count:
print('Number of total rows: ', products.shape[0])

#Missing Values:
null_cols = products.isnull().sum()
null_cols[null_cols > 0]
# Out:
# Number of total rows:  3500
# prices.shipping    1540
# ean                2901
# manufacturer       1934
# Unnamed: 26        3500
# Unnamed: 27        3494
# Unnamed: 28        3494
# Unnamed: 29        3500
# Unnamed: 30        3494
# dtype: int64

# %%
#Drop last columns as they are all almost empty:
products = products.drop(['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30'], axis=1)

# %%
#Remove 'prices.' from column names:
products.columns = products.columns.str.replace('prices.','')
products.head()
# Out:
#                      id  amountMax  amountMin availability condition currency  \
# 0  AVphzgbJLJeJML43fA0o     104.99     104.99          Yes       New      USD
# 1  AVpgMuGwLJeJML43KY_c      69.00      64.99     In Stock       New      USD
# 2  AVpgMuGwLJeJML43KY_c      69.00      69.00     In Stock       New      USD
# 3  AVpgMuGwLJeJML43KY_c      69.99      69.99          Yes       New      USD
# 4  AVpgMuGwLJeJML43KY_c      66.99      66.99          Yes       New      USD
#
#                                             dateSeen  isSale     merchant  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...   False  Bestbuy.com
# 1                               2017-12-14T06:00:00Z    True  Walmart.com
# 2                               2017-09-08T05:00:00Z   False  Walmart.com
# 3                               2017-10-10T05:00:00Z   False  Bestbuy.com
# 4                               2017-08-28T07:00:00Z   False  Bestbuy.com
#
#     shipping  ...  ean                                          imageURLs  \
# 0        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 1  Expedited  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 2  Expedited  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 3        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 4        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys manufacturer  \
# 0  sanusvlf410b110inchsuperslimfullmotionmountfor...          NaN
# 1  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 2  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 3  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 4  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
#
#   manufacturerNumber                                               name  \
# 0           VLF410B1  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#   primaryCategories                                         sourceURLs  \
# 0       Electronics  https://www.amazon.com/Sanus-VLF410B1-10-Inch-...
# 1       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 2       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 3       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 4       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
#
#            upc       weight
# 0  7.93796E+11  32.8 pounds
# 1  6.42015E+11    14 pounds
# 2  6.42015E+11    14 pounds
# 3  6.42015E+11    14 pounds
# 4  6.42015E+11    14 pounds
#
# [5 rows x 26 columns]

# %%
#check all column names:
products.columns
# Out:
# Index(['id', 'amountMax', 'amountMin', 'availability', 'condition', 'currency',
#        'dateSeen', 'isSale', 'merchant', 'shipping', 'sourceURLs', 'asins',
#        'brand', 'categories', 'dateAdded', 'dateUpdated', 'ean', 'imageURLs',
#        'keys', 'manufacturer', 'manufacturerNumber', 'name',
#        'primaryCategories', 'sourceURLs', 'upc', 'weight'],
#       dtype='object')

# %%
#Check categories for availability:
set(products['availability'])
# Out:
# {'FALSE',
#  'In Stock',
#  'More on the Way',
#  'No',
#  'Out Of Stock',
#  'Retired',
#  'Special Order',
#  'TRUE',
#  'Yes',
#  'sold',
#  'undefined',
#  'yes'}

# %%
#Clean up:
products['availability'] = products['availability'].replace('No', 'Out Of Stock')
products['availability'] = products['availability'].replace('sold', 'Out Of Stock')
products['availability'] = products['availability'].replace('FALSE', 'Out Of Stock')
products['availability'] = products['availability'].replace('TRUE', 'In Stock')
products['availability'] = products['availability'].replace('yes', 'In Stock')
products['availability'] = products['availability'].replace('Yes', 'In Stock')
products['availability'] = products['availability'].replace('More on the Way', 'Soon Back In Stock')
products['availability'] = products['availability'].replace('Special Order', 'Available On Request')

products['availability'] = products['availability'].replace('undefined', np.nan)

set(products['availability'])
# Out:
# {'Available On Request',
#  'In Stock',
#  'Out Of Stock',
#  'Retired',
#  'Soon Back In Stock',
#  nan}

# %%
#Count number per category:
products['availability'].value_counts()
# Out:
# In Stock                3303
# Out Of Stock              68
# Available On Request      52
# Soon Back In Stock        45
# Retired                    1
# Name: availability, dtype: int64

# %%
#Count products per primary category:
products['primaryCategories'].value_counts()
# Out:
# Electronics        3494
#  Siri Eyes Free       6
# Name: primaryCategories, dtype: int64

# %%
#Count products per currency:
products['currency'].value_counts()
# Out:
# USD    3500
# Name: currency, dtype: int64

# %%
# Check if all values in amountMax and amountMin columns are the same
set(products['amountMax'] == products['amountMin'])
# Out:
# {False, True}

# %%
#Fill in missing manufacturer with brand:
products.loc[(products['manufacturer'].isnull()==True), 'manufacturer'] = products['brand'] 
set(products.manufacturer)
# Out:
# {'5 Years',
#  'AOC',
#  'ASUS',
#  'AUDIOQUEST',
#  'Acer',
#  'Actiontec',
#  'AfterShokz',
#  'Aftershokz',
#  'Aiwa',
#  'Alienware',
#  'Allround Software',
#  'Alpine',
#  'Alpine Electronics USA',
#  'Anker',
#  'Antec',
#  'Apple',
#  'Arris',
#  'Atrend',
#  'AudioQuest',
#  'Audioquest',
#  'BOSE',
#  'Belkin',
#  'Bose',
#  'Bowers & Wilkins',
#  'Boytone',
#  'CORSAIR',
#  'Canon',
#  'Canon Cameras US',
#  'Case Logic',
#  'Cerwin Vega',
#  'Cerwin-Vega',
#  'Chief Manufacturing',
#  'Cooks International LLC (Former Coshell Holdings LLC)',
#  'Coolermaster',
#  'Corsair',
#  'Cybertronpc',
#  'Dantona',
#  'Definitive Technology',
#  'Dell',
#  'Denaq',
#  'Denon',
#  'Digipower',
#  'DreamWave',
#  'Dual',
#  'ECOXGEAR',
#  'ELITE SCREENS DIRECTSHIP',
#  'Elite Screens',
#  'Elitescreens',
#  'Emerge',
#  'Epson',
#  'Escort',
#  'Fitbit',
#  'G-Technology',
#  'GEKO',
#  'Garmin',
#  'GoPro',
#  'Goal Zero',
#  'Grace Digital',
#  'Grace Digital Audio',
#  'HP',
#  'Hauppauge',
#  'Hisense',
#  'House Of Marley',
#  'House of Marley',
#  'Hoya',
#  'IOGEAR',
#  'ISIMPLE',
#  'Incipio',
#  'Innovative Technology',
#  'Insignia',
#  'JBL',
#  'JVC',
#  'Jbl',
#  'Jensen',
#  'Jvc Real Sound System Z Series Ha-Sz2000 Stream Woofer Db Headphones (black, Japan Import) V-Moda',
#  'KEF',
#  'KENWOOD',
#  'KLIPSCH',
#  'Kanto',
#  'Kanto Living',
#  'Kenwood',
#  'Kicker',
#  'Klipsch',
#  'LG',
#  'Lenovo',
#  'Lenovo Corporate',
#  'Lenovo Idea',
#  'Logitech',
#  'Logitech, Inc',
#  'Lowepro',
#  'MEE audio',
#  'MSI',
#  'MTX',
#  'Manfrotto',
#  'Manufacturers Limited Warranty:1 Year',
#  'Marantz',
#  'MartinLogan',
#  'Master & Dynamic',
#  'Master Dynamic',
#  'Mee Audio',
#  'Memorex',
#  'Microsoft',
#  'Midland',
#  'Monster',
#  'Motorola',
#  'Motorola Home',
#  'NETGEAR',
#  'NVIDIA',
#  'NZXT',
#  'Netgear',
#  'Niles',
#  'Novatel',
#  'ONKYO',
#  'Olympus',
#  'Onkyo',
#  'Outdoor Tech',
#  'PANAMX',
#  'PYLE',
#  'Panamax',
#  'Panasonic',
#  'Parts',
#  'Peak Design',
#  'Peerless',
#  'Peerless Industries',
#  'Peerless-AV',
#  'Pelican',
#  'Pioneer',
#  'Planet Audio',
#  'Pny',
#  'Polaroid',
#  'Polk Audio',
#  'Power Acoustik',
#  'RAZER',
#  'RODE',
#  'Razer',
#  'Razer USA',
#  'Russound',
#  'SAMSUNG',
#  'SKB Cases',
#  'SOL REPUBLIC',
#  'SVS',
#  'Samsung',
#  'Samsung Electronics',
#  'Samsung IT',
#  'SanDisk',
#  'Sandisk',
#  'Sanus',
#  'Seagate',
#  'Seagate Technology',
#  'Sennheiser',
#  'Sharp',
#  'Sigma',
#  'SiliconDust USA, Inc',
#  'Sima',
#  'SiriusXM',
#  'Siriusxm',
#  'Skullcandy',
#  'Slingbox',
#  'Sol Republic',
#  'Sonax',
#  'Sony',
#  'SpeakerCraft',
#  'StarTech',
#  'StarTech.com',
#  'Steelseries',
#  'SunBriteTV',
#  'Sylvania',
#  'TIVO',
#  'TP-Link',
#  'TRANSCEND Storage',
#  'Tenba',
#  'Thule',
#  'TiVo',
#  'Toshiba',
#  'Tp-Link',
#  'Turtle Beach',
#  'Ultimate Ears',
#  'Universal Remote Control',
#  'V-MODA',
#  'VINPOWER DIGITAL DIRECTSHIP',
#  'VXi',
#  'ViewSonic',
#  'Viper by GLD Products',
#  'Virgin Mobile',
#  'Visidec',
#  'Vizio',
#  'WD',
#  'Wacom',
#  'Western Digital',
#  'XFX',
#  'YAMAHA',
#  'Yamaha',
#  'Yamaha Electronics',
#  'ZTE',
#  'Zagg',
#  'Zmodo',
#  'Zoom',
#  'Zubie',
#  'eTape16',
#  'iHome',
#  'j5create',
#  'kate spade new york',
#  'mophie',
#  'niles'}

# %%
null_cols = products.isnull().sum()
null_cols[null_cols > 0]
# Out:
# availability      31
# shipping        1540
# ean             2901
# dtype: int64

# %%
#Replace the incorrect value in manufacturer with brand:
products['manufacturer'] = products['manufacturer'].replace('5 Years', products['brand'])

# %%
set(products.manufacturer)
# Out:
# {'AOC',
#  'ASUS',
#  'AUDIOQUEST',
#  'Acer',
#  'Actiontec',
#  'AfterShokz',
#  'Aftershokz',
#  'Aiwa',
#  'Alienware',
#  'Allround Software',
#  'Alpine',
#  'Alpine Electronics USA',
#  'Anker',
#  'Antec',
#  'Apple',
#  'Arris',
#  'Atrend',
#  'AudioQuest',
#  'Audioquest',
#  'BOSE',
#  'Belkin',
#  'Bose',
#  'Bowers & Wilkins',
#  'Boytone',
#  'CORSAIR',
#  'Canon',
#  'Canon Cameras US',
#  'Case Logic',
#  'Cerwin Vega',
#  'Cerwin-Vega',
#  'Chief Manufacturing',
#  'Cooks International LLC (Former Coshell Holdings LLC)',
#  'Coolermaster',
#  'Corsair',
#  'Cybertronpc',
#  'Dantona',
#  'Definitive Technology',
#  'Dell',
#  'Denaq',
#  'Denon',
#  'Digipower',
#  'DreamWave',
#  'Dual',
#  'ECOXGEAR',
#  'ELITE SCREENS DIRECTSHIP',
#  'Elite Screens',
#  'Elitescreens',
#  'Emerge',
#  'Epson',
#  'Escort',
#  'Fitbit',
#  'G-Technology',
#  'GEKO',
#  'Garmin',
#  'GoPro',
#  'Goal Zero',
#  'Grace Digital',
#  'Grace Digital Audio',
#  'HP',
#  'Hauppauge',
#  'Hisense',
#  'House Of Marley',
#  'House of Marley',
#  'Hoya',
#  'IOGEAR',
#  'ISIMPLE',
#  'Incipio',
#  'Innovative Technology',
#  'Insignia',
#  'JBL',
#  'JVC',
#  'Jbl',
#  'Jensen',
#  'Jvc Real Sound System Z Series Ha-Sz2000 Stream Woofer Db Headphones (black, Japan Import) V-Moda',
#  'KEF',
#  'KENWOOD',
#  'KLIPSCH',
#  'Kanto',
#  'Kanto Living',
#  'Kenwood',
#  'Kicker',
#  'Klipsch',
#  'LG',
#  'Lenovo',
#  'Lenovo Corporate',
#  'Lenovo Idea',
#  'Logitech',
#  'Logitech, Inc',
#  'Lowepro',
#  'MEE audio',
#  'MSI',
#  'MTX',
#  'Manfrotto',
#  'Manufacturers Limited Warranty:1 Year',
#  'Marantz',
#  'MartinLogan',
#  'Master & Dynamic',
#  'Master Dynamic',
#  'Mee Audio',
#  'Memorex',
#  'Microsoft',
#  'Midland',
#  'Monster',
#  'Motorola',
#  'Motorola Home',
#  'NETGEAR',
#  'NVIDIA',
#  'NZXT',
#  'Netgear',
#  'Niles',
#  'Novatel',
#  'ONKYO',
#  'Olympus',
#  'Onkyo',
#  'Outdoor Tech',
#  'PANAMX',
#  'PYLE',
#  'Panamax',
#  'Panasonic',
#  'Parts',
#  'Peak Design',
#  'Peerless',
#  'Peerless Industries',
#  'Peerless-AV',
#  'Pelican',
#  'Pioneer',
#  'Planet Audio',
#  'Pny',
#  'Polaroid',
#  'Polk Audio',
#  'Power Acoustik',
#  'RAZER',
#  'RODE',
#  'Razer',
#  'Razer USA',
#  'Russound',
#  'SAMSUNG',
#  'SKB Cases',
#  'SOL REPUBLIC',
#  'SVS',
#  'Samsung',
#  'Samsung Electronics',
#  'Samsung IT',
#  'SanDisk',
#  'Sandisk',
#  'Sanus',
#  'Seagate',
#  'Seagate Technology',
#  'Sennheiser',
#  'Sharp',
#  'Sigma',
#  'SiliconDust USA, Inc',
#  'Sima',
#  'SiriusXM',
#  'Siriusxm',
#  'Skullcandy',
#  'Slingbox',
#  'Sol Republic',
#  'Sonax',
#  'Sony',
#  'SpeakerCraft',
#  'StarTech',
#  'StarTech.com',
#  'Steelseries',
#  'SunBriteTV',
#  'Sylvania',
#  'TIVO',
#  'TP-Link',
#  'TRANSCEND Storage',
#  'Tenba',
#  'Thule',
#  'TiVo',
#  'Toshiba',
#  'Tp-Link',
#  'Turtle Beach',
#  'Ultimate Ears',
#  'Universal Remote Control',
#  'V-MODA',
#  'VINPOWER DIGITAL DIRECTSHIP',
#  'VXi',
#  'ViewSonic',
#  'Viper by GLD Products',
#  'Virgin Mobile',
#  'Visidec',
#  'Vizio',
#  'WD',
#  'Wacom',
#  'Western Digital',
#  'XFX',
#  'YAMAHA',
#  'Yamaha',
#  'Yamaha Electronics',
#  'ZTE',
#  'Zagg',
#  'Zmodo',
#  'Zoom',
#  'Zubie',
#  'eTape16',
#  'iHome',
#  'j5create',
#  'kate spade new york',
#  'mophie',
#  'niles'}

# %%
products.head()
# Out:
#                      id  amountMax  amountMin availability condition currency  \
# 0  AVphzgbJLJeJML43fA0o     104.99     104.99     In Stock       New      USD
# 1  AVpgMuGwLJeJML43KY_c      69.00      64.99     In Stock       New      USD
# 2  AVpgMuGwLJeJML43KY_c      69.00      69.00     In Stock       New      USD
# 3  AVpgMuGwLJeJML43KY_c      69.99      69.99     In Stock       New      USD
# 4  AVpgMuGwLJeJML43KY_c      66.99      66.99     In Stock       New      USD
#
#                                             dateSeen  isSale     merchant  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...   False  Bestbuy.com
# 1                               2017-12-14T06:00:00Z    True  Walmart.com
# 2                               2017-09-08T05:00:00Z   False  Walmart.com
# 3                               2017-10-10T05:00:00Z   False  Bestbuy.com
# 4                               2017-08-28T07:00:00Z   False  Bestbuy.com
#
#     shipping  ...  ean                                          imageURLs  \
# 0        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 1  Expedited  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 2  Expedited  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 3        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
# 4        NaN  ...  NaN  https://images-na.ssl-images-amazon.com/images...
#
#                                                 keys manufacturer  \
# 0  sanusvlf410b110inchsuperslimfullmotionmountfor...        Sanus
# 1  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 2  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 3  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
# 4  boytone2500w21chhometheatersystemblackdiamond/...      Boytone
#
#   manufacturerNumber                                               name  \
# 0           VLF410B1  Sanus VLF410B1 10-Inch Super Slim Full-Motion ...
# 1            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 2            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 3            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
# 4            BT-210F  Boytone - 2500W 2.1-Ch. Home Theater System - ...
#
#   primaryCategories                                         sourceURLs  \
# 0       Electronics  https://www.amazon.com/Sanus-VLF410B1-10-Inch-...
# 1       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 2       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 3       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
# 4       Electronics  http://reviews.bestbuy.com/3545/4784804/review...
#
#            upc       weight
# 0  7.93796E+11  32.8 pounds
# 1  6.42015E+11    14 pounds
# 2  6.42015E+11    14 pounds
# 3  6.42015E+11    14 pounds
# 4  6.42015E+11    14 pounds
#
# [5 rows x 26 columns]

# %%
#Export csv:
products.to_csv('../output/electronics_clean.csv', index=False)
