# %%
import numpy

# %%
import scipy

# %%
from sklearn import datasets
diabetesDataset = datasets.load_diabetes()

# %%
diabetesDataset.data
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990842, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06832974, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286377, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04687948,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452837, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00421986,  0.00306441]])

# %%
diabetesDataset.target
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %% [markdown]
# # Loading Datasets into Scikit-learn

# %%
from sklearn import datasets

# dictionary-like object
diabetesDataset = datasets.load_diabetes()

# Print all attributes
diabetesDataset.keys()
# Out:
# dict_keys(['data', 'target', 'DESCR', 'feature_names', 'data_filename', 'target_filename'])

# %%
# CSV
import pandas as pd

census = pd.read_csv('../../lab-supervised-learning-feature-extraction/acs2015_county_data.csv')

# %%
census.shape
# Out:
# (3220, 37)

# %%
census.dtypes
# Out:
# CensusId             int64
# State               object
# County              object
# TotalPop             int64
# Men                  int64
# Women                int64
# Hispanic           float64
# White              float64
# Black              float64
# Native             float64
# Asian              float64
# Pacific            float64
# Citizen              int64
# Income             float64
# IncomeErr          float64
# IncomePerCap         int64
# IncomePerCapErr      int64
# Poverty            float64
# ChildPoverty       float64
# Professional       float64
# Service            float64
# Office             float64
# Construction       float64
# Production         float64
# Drive              float64
# Carpool            float64
# Transit            float64
# Walk               float64
# OtherTransp        float64
# WorkAtHome         float64
# MeanCommute        float64
# Employed             int64
# PrivateWork        float64
# PublicWork         float64
# ...

# %%
# When no column names, we name the columns ourselves by creating a list of column names. 
# For example, we have here a dataset with student name and age:
# column_list = ['name', 'age']
# df = pd.read_csv(path, header=None, names=column_list)

# %%
# JSON
#df = pd.read_json(path)

# %%
import json
try:
    from urllib.request import urlopen
except ImportError:
    from urllib2 import urlopen
import pandas as pd
from pandas.io.json import json_normalize

url = 'https://raw.githubusercontent.com/Biuni/PokemonGO-Pokedex/master/pokedex.json'
#In Python3 we will need to decode the data as well, hence the use of the decode function
url_read = urlopen(url).read().decode()
url_json = json.loads(url_read)

# %%
url_json
# Out:
# {'pokemon': [{'id': 1,
#    'num': '001',
#    'name': 'Bulbasaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/001.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.71 m',
#    'weight': '6.9 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 25,
#    'egg': '2 km',
#    'spawn_chance': 0.69,
#    'avg_spawns': 69,
#    'spawn_time': '20:00',
#    'multipliers': [1.58],
#    'weaknesses': ['Fire', 'Ice', 'Flying', 'Psychic'],
#    'next_evolution': [{'num': '002', 'name': 'Ivysaur'},
#     {'num': '003', 'name': 'Venusaur'}]},
#   {'id': 2,
#    'num': '002',
#    'name': 'Ivysaur',
#    'img': 'http://www.serebii.net/pokemongo/pokemon/002.png',
#    'type': ['Grass', 'Poison'],
#    'height': '0.99 m',
#    'weight': '13.0 kg',
#    'candy': 'Bulbasaur Candy',
#    'candy_count': 100,
#    'egg': 'Not in Eggs',
#    'spawn_chance': 0.042,
#    'avg_spawns': 4.2,
#    'spawn_time': '07:00',
#    'multipliers': [1.2, 1.6],
# ...

# %%
url_json.keys()
# Out:
# dict_keys(['pokemon'])

# %%
pokemon = json_normalize(url_json['pokemon'])
pokemon
# Out:
#      avg_spawns                     candy  candy_count            egg  height  \
# 0        69.000           Bulbasaur Candy         25.0           2 km  0.71 m
# 1         4.200           Bulbasaur Candy        100.0    Not in Eggs  0.99 m
# 2         1.700           Bulbasaur Candy          NaN    Not in Eggs  2.01 m
# 3        25.300          Charmander Candy         25.0           2 km  0.61 m
# 4         1.200          Charmander Candy        100.0    Not in Eggs  1.09 m
# 5         0.310          Charmander Candy          NaN    Not in Eggs  1.70 m
# 6        58.000            Squirtle Candy         25.0           2 km  0.51 m
# 7         3.400            Squirtle Candy        100.0    Not in Eggs  0.99 m
# 8         0.670            Squirtle Candy          NaN    Not in Eggs  1.60 m
# 9       303.200            Caterpie Candy         12.0           2 km  0.30 m
# 10       18.700            Caterpie Candy         50.0    Not in Eggs  0.71 m
# ...

# %%
# Dataset Generator:
from sklearn import datasets

featureVectors, targets = datasets.make_classification(amt_instances, amt_features, amt_classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1de5d3ca3997> in <module>
#       2 from sklearn import datasets
#       3
# ----> 4 featureVectors, targets = datasets.make_classification(amt_instances, amt_features, amt_classes)
#
# NameError: name 'amt_instances' is not defined
