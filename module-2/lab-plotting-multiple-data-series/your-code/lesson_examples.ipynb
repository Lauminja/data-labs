# %% [markdown]
# # Plotting Multiple Data Series

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
vehicles = pd.read_csv('/Users/laumaustupa/Desktop/Ironhack/Cours/data-labs/module-1/lab-import-export/vehicles/vehicles.csv')

# %%
#Multiple Line Plots
vehicles.sort_values(by=["CO2 Emission Grams/Mile", "City MPG", "Highway MPG"], inplace=True)
vehicles.plot(x="CO2 Emission Grams/Mile", y=["City MPG", "Highway MPG"])

# %%
#Multiple Bar Plots
#Side By Side Bar Plots
vehicles_mean = vehicles[["Highway MPG", "City MPG", "Drivetrain"]].groupby(["Drivetrain"]).agg("mean")
vehicles_mean.plot.bar()

# %%
#Side By Side Horizontal Bar Plots
vehicles_mean.plot.barh()

# %%
#Scatter Matrices

pd.plotting.scatter_matrix(vehicles)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c24400a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c24360b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c24387fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23f46588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23ee3b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23f130b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23eaf630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c234d7be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c234d7c18>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c22b6e6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c22b92c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23008208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2324d780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c23270cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c234912b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2368a828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c236afda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2478d358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c247b28d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c25966e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26199400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c261bf978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c261e5ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c267d64a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c267f9a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2681ef98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2684b550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c2686fac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2689e080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c268c25f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c268e6b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26914128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2693c6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26960c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c2698c1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c269b0748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c269d6cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26a03278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26a2a7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26a4cd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26a79320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26a9f898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26ac4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26af13c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26b15940>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26b3beb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26b68470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26b8c9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26bb2f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26bdf518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26c06a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26c34048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26c575c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26c7ab38>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26ca80f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26cce668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26cf0be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26d1f198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26d44710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26d6ac88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26d97240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26dba7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26de0d30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c26e0d2e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26e33860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26e5edd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26e8e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26eb5908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26ee1e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26f0f438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c26f369b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c238a8978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1c22e900b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c252cb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c24b9b470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c241ef780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c25020588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c253422b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c232950b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c24c79630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1c24206ba8>]],
#       dtype=object)
